# %%
import itertools
import math

import pandas as pd

# %% [markdown]
#  ## inputs
#  ####################################################################################################

# %%
factor_levels = {
    # fmt: off
    "A": ["P1", "P2", "P3", "Missing"],
    "B": ["r1", "r2"],
    "C": ["in", "out"],
    "D": ["US", "EU", "APAC"],
    # fmt: on
}
factor_levels
# Out:
# {'A': ['P1', 'P2', 'P3', 'Missing'],
#  'B': ['r1', 'r2'],
#  'C': ['in', 'out'],
#  'D': ['US', 'EU', 'APAC']}

# %% [markdown]
#  ## possibilities
#  ####################################################################################################

# %%
key_factor_levels = {
    # fmt: off
    "A": ["P1", "P2"],
    "B": ["r1", ],
    "C": ["in", "out"],
    "D": [],
    # fmt: on
}
key_factor_levels
# Out:
# {'A': ['P1', 'P2'], 'B': ['r1'], 'C': ['in', 'out'], 'D': []}

# %%
factor_levels_wo_factor_a = {k: v for k, v in factor_levels.items() if k != "A"}
factor_levels_wo_factor_a
# Out:
# {'B': ['r1', 'r2'], 'C': ['in', 'out'], 'D': ['US', 'EU', 'APAC']}

# %%
levels = [len(l) for l in factor_levels.values()]
levels
# Out:
# [4, 2, 2, 3]

# %%
levels_plus_1 = [i + 1 for i in levels]
levels_plus_1
# Out:
# [5, 3, 3, 4]

# %%
n = 3
n_combos_example = [math.comb(n, r) for r in range(2, n)]
n_combos_example
# Out:
# [3]

# %%
pure_multi_levels = [sum(math.comb(n, r) for r in range(2, n)) for n in levels]
pure_multi_levels
# Out:
# [10, 0, 0, 3]

# %%
multi_levels = [a + b for a, b in zip(levels_plus_1, pure_multi_levels)]
multi_levels
# Out:
# [15, 3, 3, 7]

# %%
n_all_choose_all = 1

n_one_by_one = sum(levels)
n_one_by_one_wo_a = sum(len(l) for k, l in factor_levels_wo_factor_a.items())

n_cartesian_product = math.prod(levels)

n_single_choice_all_combos = math.prod(levels_plus_1)

n_single_choice_all_combos_wo_a = math.prod(
    i + 1 for i in [len(l) for k, l in factor_levels_wo_factor_a.items()]
)
n_single_choice_all_combos_key = math.prod(
    i + 1 for i in [len(l) for k, l in key_factor_levels.items()]
)

n_multi_choice_all_combos = math.prod(multi_levels)

# %%
print(f"{n_all_choose_all = }")
print("")
print(f"{n_one_by_one = }")
print(f"{n_one_by_one_wo_a = }")
print("")
print(f"{n_cartesian_product = }")
print(f"{n_single_choice_all_combos = }")
print("")
print(f"{n_single_choice_all_combos_wo_a = }")
print(f"{n_single_choice_all_combos_key = }")
print("")
print(f"{n_multi_choice_all_combos = }")
# Out:
# n_all_choose_all = 1
#
# n_one_by_one = 11
# n_one_by_one_wo_a = 7
#
# n_cartesian_product = 48
# n_single_choice_all_combos = 180
#
# n_single_choice_all_combos_wo_a = 36
# n_single_choice_all_combos_key = 18
#
# n_multi_choice_all_combos = 945
