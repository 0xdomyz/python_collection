# %%
import aiohttp
import gzip
from dataclasses import dataclass
import re
from typing import Dict, List, Set, Iterable, Optional

# %%
CRAN_PACKAGES_URL = "https://cran.r-project.org/src/contrib/PACKAGES.gz"


@dataclass
class PackageMetadata:
    name: str
    version: str
    depends: List[str]
    imports: List[str]
    linking_to: List[str]
    suggests: List[str]


def _remove_version_constraints(token: str) -> str:
    """
    Remove version constraints in parentheses.
    e.g. 'dplyr (>= 1.0.0)' -> 'dplyr'
    """
    # Remove anything in parentheses, including space before
    return re.sub(r"\s*\(.*?\)", "", token).strip()


def _extract_dependencies(dep_string: Optional[str]) -> List[str]:
    """
    Turn a CRAN dependency string into a list of package names.

    Example:
        "R (>= 3.5.0), ggplot2, dplyr (>= 1.0.0)"
        -> ["ggplot2", "dplyr"]
    """
    if not dep_string:
        return []

    deps: List[str] = []
    for token in dep_string.split(","):
        token = token.strip()
        if not token:
            continue
        token = _remove_version_constraints(token)
        if not token or token == "R":
            continue
        deps.append(token)
    return deps


def _parse_packages_text(text: str) -> Dict[str, PackageMetadata]:
    """
    Parse the PACKAGES file content (plain text) into a dict:
        name -> PackageMetadata
    """
    index: Dict[str, PackageMetadata] = {}

    # Records are separated by blank lines
    blocks = text.strip().split("\n\n")
    for block in blocks:
        if not block.strip():
            continue

        fields = {}
        for line in block.splitlines():
            if not line.strip():
                continue
            # Handle possible continuation lines (indented)
            if line[0].isspace():
                # continuation of previous key
                last_key = next(reversed(fields))
                fields[last_key] += " " + line.strip()
                continue

            if ":" not in line:
                continue
            key, value = line.split(":", 1)
            fields[key.strip()] = value.strip()

        name = fields.get("Package")
        version = fields.get("Version")
        if not name or not version:
            continue

        meta = PackageMetadata(
            name=name,
            version=version,
            depends=_extract_dependencies(fields.get("Depends")),
            imports=_extract_dependencies(fields.get("Imports")),
            linking_to=_extract_dependencies(fields.get("LinkingTo")),
            suggests=_extract_dependencies(fields.get("Suggests")),
        )
        index[name] = meta

    return index


async def load_cran_index(session: aiohttp.ClientSession) -> Dict[str, PackageMetadata]:
    """
    Download and parse PACKAGES.gz from CRAN.
    """
    async with session.get(CRAN_PACKAGES_URL) as resp:
        resp.raise_for_status()
        data = await resp.read()

    text = gzip.decompress(data).decode("utf-8", errors="replace")
    return _parse_packages_text(text)

# %%
import aiohttp
import asyncio
import gzip

CRAN_PACKAGES_URL = "https://cran.r-project.org/src/contrib/PACKAGES.gz"

# Global reusable index
CRAN_INDEX = None


async def build_cran_index():
    """
    Download PACKAGES.gz from CRAN, parse it using your existing
    _parse_packages_text() function, and store it in CRAN_INDEX.
    """
    global CRAN_INDEX

    async with aiohttp.ClientSession() as session:
        async with session.get(CRAN_PACKAGES_URL) as resp:
            resp.raise_for_status()
            raw = await resp.read()

    text = gzip.decompress(raw).decode("utf-8", errors="replace")

    # Use YOUR parser from Section 1.2
    CRAN_INDEX = _parse_packages_text(text)

    print(f"CRAN index built with {len(CRAN_INDEX)} packages.")


# Run it once to build the index
await build_cran_index()
# Out:
# CRAN index built with 23082 packages.

# %%
CRAN_INDEX
# Out:
# {'AalenJohansen': PackageMetadata(name='AalenJohansen', version='1.0', depends=[], imports=[], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'aamatch': PackageMetadata(name='aamatch', version='0.3.7', depends=[], imports=['iTOS', 'stats'], linking_to=[], suggests=['DOS2', 'sensitivity2x2xk', 'sensitivitymv', 'weightedRank', 'xtable']),
#  'AATtools': PackageMetadata(name='AATtools', version='0.0.3', depends=[], imports=['magrittr', 'dplyr', 'doParallel', 'foreach'], linking_to=[], suggests=[]),
#  'ABACUS': PackageMetadata(name='ABACUS', version='1.0.0', depends=[], imports=['ggplot2', 'shiny'], linking_to=[], suggests=['rmarkdown', 'knitr']),
#  'abasequence': PackageMetadata(name='abasequence', version='0.1.0', depends=[], imports=[], linking_to=[], suggests=[]),
#  'abbreviate': PackageMetadata(name='abbreviate', version='0.1', depends=[], imports=[], linking_to=[], suggests=['testthat']),
#  'abc': PackageMetadata(name='abc', version='2.2.2', depends=['abc.data', 'nnet', 'quantreg', 'MASS', 'locfit'], imports=[], linking_to=[], suggests=[]),
#  'abc.data': PackageMetadata(name='abc.data', version='1.1', depends=[], imports=[], linking_to=[], suggests=[]),
#  'ABC.RAP': PackageMetadata(name='ABC.RAP', version='0.9.0', depends=[], imports=['graphics', 'stats', 'utils'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'ABCanalysis': PackageMetadata(name='ABCanalysis', version='1.2.1', depends=[], imports=['plotrix'], linking_to=[], suggests=[]),
#  'ABCDscores': PackageMetadata(name='ABCDscores', version='6.1.0', depends=[], imports=['chk', 'cli', 'dplyr', 'glue', 'lubridate', 'magrittr', 'purrr', 'rlang', 'stringr', 'tibble', 'tidyr', 'stats', 'utils'], linking_to=[], suggests=['arrow', 'rmarkdown', 'roxyglobals', 'testthat', 'knitr', 'reactable', 'readr', 'usethis']),
#  'abcel': PackageMetadata(name='abcel', version='1.0', depends=[], imports=['MASS', 'emplik', 'methods', 'FNN', 'corpcor'], linking_to=[], suggests=[]),
#  'abclass': PackageMetadata(name='abclass', version='0.5.0', depends=[], imports=['Rcpp', 'graphics', 'parallel', 'stats'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=['Matrix', 'Rglpk', 'qpmadr', 'tinytest']),
#  'ABCoptim': PackageMetadata(name='ABCoptim', version='0.15.0', depends=[], imports=['Rcpp', 'graphics', 'stats', 'utils'], linking_to=['Rcpp'], suggests=['testthat', 'covr']),
#  'abcrf': PackageMetadata(name='abcrf', version='2.0', depends=[], imports=['readr', 'MASS', 'matrixStats', 'ranger', 'doParallel', 'parallel', 'foreach', 'stringr', 'Rcpp'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=[]),
#  'abcrlda': PackageMetadata(name='abcrlda', version='1.0.3', depends=[], imports=['stats'], linking_to=[], suggests=[]),
#  'abctools': PackageMetadata(name='abctools', version='1.1.8', depends=['abc', 'abind', 'parallel', 'plyr', 'Hmisc'], imports=['methods'], linking_to=[], suggests=['ggplot2', 'abc.data']),
#  'abd': PackageMetadata(name='abd', version='0.2-8', depends=['nlme', 'lattice', 'grid', 'mosaic'], imports=[], linking_to=[], suggests=['boot', 'car', 'ggplot2', 'plyr', 'HH', 'ICC', 'vcd', 'Hmisc']),
#  'abdiv': PackageMetadata(name='abdiv', version='0.2.0', depends=[], imports=['ape'], linking_to=[], suggests=['testthat', 'vegan']),
#  'abe': PackageMetadata(name='abe', version='5.1.2', depends=[], imports=['ggplot2', 'reshape2', 'tidytext', 'survival', 'foreach', 'lifecycle'], linking_to=[], suggests=['testthat']),
#  'aberrance': PackageMetadata(name='aberrance', version='0.3.0', depends=[], imports=['graphics', 'grDevices', 'MASS', 'Rcpp', 'stats', 'utils'], linking_to=['Rcpp'], suggests=[]),
#  'abess': PackageMetadata(name='abess', version='0.4.11', depends=[], imports=['Rcpp', 'MASS', 'methods', 'Matrix', 'igraph'], linking_to=['Rcpp', 'RcppEigen'], suggests=['testthat', 'knitr', 'rmarkdown']),
#  'abglasso': PackageMetadata(name='abglasso', version='0.1.1', depends=[], imports=['MASS', 'pracma', 'stats', 'statmod'], linking_to=[], suggests=['testthat']),
#  'ABHgenotypeR': PackageMetadata(name='ABHgenotypeR', version='1.0.1', depends=[], imports=['ggplot2', 'reshape2', 'utils'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'abima': PackageMetadata(name='abima', version='1.1', depends=[], imports=['boot', 'stats'], linking_to=[], suggests=['testthat']),
#  'abind': PackageMetadata(name='abind', version='1.4-8', depends=[], imports=['methods', 'utils'], linking_to=[], suggests=[]),
#  'abjData': PackageMetadata(name='abjData', version='1.1.2', depends=[], imports=[], linking_to=[], suggests=[]),
#  'abjutils': PackageMetadata(name='abjutils', version='0.3.2', depends=[], imports=['dplyr', 'magrittr', 'purrr', 'rlang', 'rstudioapi', 'stringi', 'stringr', 'tidyr'], linking_to=[], suggests=['testthat']),
#  'ablasso': PackageMetadata(name='ablasso', version='1.1', depends=[], imports=['hdm', 'matrixStats', 'mvtnorm', 'stats'], linking_to=[], suggests=[]),
#  'ABM': PackageMetadata(name='ABM', version='0.4.3', depends=[], imports=['R6', 'Rcpp'], linking_to=['Rcpp'], suggests=[]),
#  'abms': PackageMetadata(name='abms', version='0.2', depends=[], imports=['BayesLogit', 'GIGrvg', 'mvtnorm', 'truncnorm'], linking_to=[], suggests=[]),
#  'abn': PackageMetadata(name='abn', version='3.1.12', depends=[], imports=['doParallel', 'foreach', 'glmmTMB', 'graph', 'jsonlite', 'lme4', 'mclogit', 'methods', 'nnet', 'Rcpp', 'Rgraphviz', 'rjags', 'stringi'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=['bookdown', 'boot', 'brglm', 'devtools', 'ggplot2', 'gridExtra', 'INLA', 'knitr', 'Matrix', 'MatrixModels', 'microbenchmark', 'R.rsp', 'RhpcBLASctl', 'rmarkdown', 'testthat', 'entropy', 'moments', 'R6']),
#  'abnormality': PackageMetadata(name='abnormality', version='0.1.0', depends=[], imports=['MASS', 'Matrix'], linking_to=[], suggests=[]),
#  'abodOutlier': PackageMetadata(name='abodOutlier', version='0.1', depends=['cluster'], imports=[], linking_to=[], suggests=[]),
#  'ABPS': PackageMetadata(name='ABPS', version='0.3', depends=[], imports=['kernlab'], linking_to=[], suggests=['testthat']),
#  'ABRSQOL': PackageMetadata(name='ABRSQOL', version='1.0.0', depends=[], imports=[], linking_to=[], suggests=['testthat']),
#  'abseil': PackageMetadata(name='abseil', version='2023.8.2.1', depends=[], imports=[], linking_to=[], suggests=['Rcpp']),
#  'absorber': PackageMetadata(name='absorber', version='1.0', depends=['Matrix', 'sparsegl', 'fda', 'parallel'], imports=['ggplot2', 'MASS', 'irlba'], linking_to=[], suggests=['knitr', 'markdown']),
#  'abstr': PackageMetadata(name='abstr', version='0.4.2', depends=[], imports=['jsonlite', 'lwgeom', 'magrittr', 'methods', 'od', 'sf', 'tibble', 'tidyr'], linking_to=[], suggests=['knitr', 'dplyr', 'rmarkdown', 'tmap', 'pct', 'foreign']),
#  'abstractr': PackageMetadata(name='abstractr', version='0.1.0', depends=[], imports=['shiny', 'ggplot2', 'gridExtra', 'colourpicker', 'shinythemes', 'emojifont', 'rintrojs'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'ABSurvTDC': PackageMetadata(name='ABSurvTDC', version='0.1.0', depends=[], imports=['stats', 'survival', 'readxl'], linking_to=[], suggests=[]),
#  'abtest': PackageMetadata(name='abtest', version='1.0.1', depends=[], imports=['Rcpp', 'mvtnorm', 'sn', 'qgam', 'truncnorm', 'plotrix', 'grDevices', 'RColorBrewer', 'Matrix', 'parallel'], linking_to=['Rcpp'], suggests=['testthat']),
#  'abundant': PackageMetadata(name='abundant', version='1.2', depends=['glasso'], imports=[], linking_to=[], suggests=[]),
#  'abwm': PackageMetadata(name='abwm', version='0.1.0', depends=[], imports=['stats'], linking_to=[], suggests=['gtools', 'testthat']),
#  'Ac3net': PackageMetadata(name='Ac3net', version='1.2.2', depends=['data.table'], imports=[], linking_to=[], suggests=[]),
#  'ACA': PackageMetadata(name='ACA', version='1.1', depends=[], imports=['graphics', 'grDevices', 'stats', 'utils'], linking_to=[], suggests=[]),
#  'AcademicThemes': PackageMetadata(name='AcademicThemes', version='0.0.2', depends=[], imports=['ggplot2', 'grDevices'], linking_to=[], suggests=['covr', 'knitr', 'rmarkdown', 'scales', 'testthat', 'tidyverse']),
#  'academictwitteR': PackageMetadata(name='academictwitteR', version='0.3.1', depends=[], imports=['dplyr', 'httr', 'jsonlite', 'magrittr', 'lubridate', 'usethis', 'tibble', 'tidyr', 'tidyselect', 'purrr', 'rlang', 'utils'], linking_to=[], suggests=['knitr', 'rmarkdown', 'devtools', 'testthat', 'httptest', 'lifecycle', 'covr']),
#  'acc': PackageMetadata(name='acc', version='1.3.3', depends=['mhsmm'], imports=['zoo', 'PhysicalActivity', 'nleqslv', 'plyr', 'methods', 'DBI', 'RSQLite', 'circlize', 'ggplot2', 'R.utils', 'iterators', 'Rcpp'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=[]),
#  'acca': PackageMetadata(name='acca', version='0.2', depends=[], imports=['methods', 'stats', 'ggplot2', 'plyr'], linking_to=[], suggests=[]),
#  'accelerometry': PackageMetadata(name='accelerometry', version='3.1.2', depends=[], imports=['Rcpp', 'dvmisc'], linking_to=['Rcpp'], suggests=['knitr', 'rmarkdown', 'pander']),
#  'accelmissing': PackageMetadata(name='accelmissing', version='2.2', depends=['mice', 'pscl'], imports=[], linking_to=[], suggests=[]),
#  'AccelStab': PackageMetadata(name='AccelStab', version='2.3.2', depends=[], imports=['dplyr', 'ggplot2', 'minpack.lm', 'stats', 'scales'], linking_to=[], suggests=['testthat', 'knitr', 'rmarkdown', 'lifecycle']),
#  'accept': PackageMetadata(name='accept', version='1.0.2', depends=[], imports=['stats', 'tidyselect', 'dplyr', 'reldist', 'splines', 'tibble', 'hardhat', 'vctrs', 'vetiver'], linking_to=[], suggests=['jsonlite', 'plotly', 'spelling', 'testthat']),
#  'AcceptanceSampling': PackageMetadata(name='AcceptanceSampling', version='1.0.11', depends=['methods', 'stats'], imports=['graphics', 'utils'], linking_to=[], suggests=[]),
#  'AcceptReject': PackageMetadata(name='AcceptReject', version='0.1.2', depends=[], imports=['assertthat', 'cli', 'ggplot2', 'glue', 'numDeriv', 'purrr', 'Rcpp', 'rlang', 'scales', 'scattermore'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=['knitr', 'rmarkdown', 'cowplot', 'tictoc', 'testthat']),
#  'accessibility': PackageMetadata(name='accessibility', version='1.4.0', depends=[], imports=['checkmate', 'data.table', 'Hmisc', 'Rdpack', 'stats', 'utils'], linking_to=[], suggests=['covr', 'ggplot2', 'knitr', 'rmarkdown', 'sf', 'testthat', 'tibble']),
#  'accessr': PackageMetadata(name='accessr', version='1.1.3', depends=[], imports=['rmarkdown'], linking_to=[], suggests=['dplyr', 'knitr', 'flextable', 'htmltools', 'huxtable', 'jpeg', 'officer', 'officedown', 'pagedown', 'png', 'tools', 'utils', 'xfun', 'zip', 'testthat']),
#  'accessrmd': PackageMetadata(name='accessrmd', version='1.0.0', depends=['ggplot2'], imports=['htmltools', 'stringr', 'rlist', 'knitr', 'RCurl'], linking_to=[], suggests=['testthat', 'rmarkdown', 'markdown', 'covr']),
#  'accrual': PackageMetadata(name='accrual', version='1.4', depends=['tcltk2'], imports=['fgui', 'SMPracticals'], linking_to=[], suggests=[]),
#  'accrualPlot': PackageMetadata(name='accrualPlot', version='1.0.7', depends=['lubridate'], imports=['dplyr', 'ggplot2', 'grid', 'magrittr', 'purrr', 'rlang'], linking_to=[], suggests=['knitr', 'markdown', 'patchwork', 'rmarkdown', 'testthat', 'vdiffr']),
#  'AccSamplingDesign': PackageMetadata(name='AccSamplingDesign', version='0.0.7', depends=[], imports=['stats', 'methods'], linking_to=[], suggests=['VGAM', 'knitr', 'rmarkdown']),
#  'accSDA': PackageMetadata(name='accSDA', version='1.1.3', depends=[], imports=['MASS', 'ggplot2', 'grid', 'gridExtra'], linking_to=[], suggests=[]),
#  'accucor': PackageMetadata(name='accucor', version='0.3.1', depends=[], imports=['nnls', 'dplyr', 'stringr', 'readxl', 'readr', 'rlang', 'tibble', 'writexl', 'CHNOSZ'], linking_to=[], suggests=['testthat']),
#  'accumulate': PackageMetadata(name='accumulate', version='1.0.0', depends=[], imports=[], linking_to=[], suggests=['tinytest', 'simplermarkdown', 'validate']),
#  'acdcquery': PackageMetadata(name='acdcquery', version='1.1.1', depends=[], imports=['DBI', 'RSQLite'], linking_to=[], suggests=[]),
#  'acdcR': PackageMetadata(name='acdcR', version='1.0.0', depends=['raster', 'data.table', 'stats'], imports=[], linking_to=[], suggests=[]),
#  'ACDm': PackageMetadata(name='ACDm', version='1.1.0', depends=[], imports=['broom', 'dplyr', 'ggplot2', 'graphics', 'numDeriv', 'plyr', 'Rcpp', 'Rsolnp', 'zoo'], linking_to=['Rcpp'], suggests=['optimx', 'rgl']),
#  'ACE.CoCo': PackageMetadata(name='ACE.CoCo', version='0.1', depends=[], imports=['quantreg'], linking_to=[], suggests=['mvtnorm', 'MASS']),
#  'ace2fastq': PackageMetadata(name='ace2fastq', version='0.6.0', depends=[], imports=['stringr'], linking_to=[], suggests=['testthat', 'knitr', 'rmarkdown', 'covr']),
#  'acebayes': PackageMetadata(name='acebayes', version='1.11', depends=['lhs'], imports=['Rcpp', 'compare', 'randtoolbox', 'parallel'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=[]),
#  'aceEditor': PackageMetadata(name='aceEditor', version='1.0.1', depends=[], imports=['htmltools', 'htmlwidgets', 'reactR', 'rstudioapi', 'tools'], linking_to=[], suggests=[]),
#  'ACEP': PackageMetadata(name='ACEP', version='0.0.22', depends=[], imports=['graphics', 'stats', 'httr'], linking_to=[], suggests=['covr', 'testthat']),
#  'acepack': PackageMetadata(name='acepack', version='1.6.3', depends=[], imports=[], linking_to=[], suggests=['testthat', 'roxygen2']),
#  'ACEsearch': PackageMetadata(name='ACEsearch', version='1.0.0', depends=[], imports=['httr', 'testthat'], linking_to=[], suggests=[]),
#  'ACEsimFit': PackageMetadata(name='ACEsimFit', version='0.0.0.9', depends=[], imports=['OpenMx', 'stats'], linking_to=[], suggests=['knitr', 'testthat', 'rmarkdown']),
#  'ACEt': PackageMetadata(name='ACEt', version='1.9.0', depends=[], imports=['Rcpp', 'splines', 'MASS', 'methods'], linking_to=['BH', 'RcppArmadillo', 'Rcpp'], suggests=['knitr', 'rmarkdown']),
#  'acfMPeriod': PackageMetadata(name='acfMPeriod', version='1.0.0', depends=['MASS'], imports=[], linking_to=[], suggests=[]),
#  'Achilles': PackageMetadata(name='Achilles', version='1.7.2', depends=['DatabaseConnector'], imports=['SqlRender', 'dplyr', 'jsonlite', 'ParallelLogger', 'readr', 'data.table', 'lubridate', 'tseries', 'rlang'], linking_to=[], suggests=['DT', 'magrittr', 'tidyr', 'knitr', 'rmarkdown', 'testthat', 'withr']),
#  'acid': PackageMetadata(name='acid', version='1.1', depends=['gamlss', 'gamlss.dist', 'Hmisc', 'stats', 'graphics', 'splines'], imports=['grDevices', 'utils', 'datasets', 'methods'], linking_to=[], suggests=['ineq']),
#  'acled.api': PackageMetadata(name='acled.api', version='1.1.8', depends=[], imports=['httr', 'jsonlite'], linking_to=[], suggests=['testthat']),
#  'acledR': PackageMetadata(name='acledR', version='1.0.1', depends=[], imports=['dplyr', 'methods', 'httr', 'httr2', 'lubridate', 'stringr', 'tidyr', 'magrittr', 'purrr', 'rlang', 'lifecycle', 'utils'], linking_to=[], suggests=['knitr', 'janitor', 'rmarkdown', 'readr', 'kableExtra', 'ggplot2', 'covr', 'here', 'secret', 'sf', 'raster', 'forcats', 'igraph', 'sjmisc', 'testthat']),
#  'aclhs': PackageMetadata(name='aclhs', version='1.0.1', depends=[], imports=['DEoptim', 'geoR', 'graphics', 'stats', 'utils'], linking_to=[], suggests=['testthat']),
#  'acmgscaler': PackageMetadata(name='acmgscaler', version='1.0.0', depends=[], imports=[], linking_to=[], suggests=[]),
#  'ACNE': PackageMetadata(name='ACNE', version='0.9.2', depends=['aroma.affymetrix'], imports=['MASS', 'R.methodsS3', 'R.oo', 'R.utils', 'matrixStats', 'R.filesets', 'aroma.core'], linking_to=[], suggests=['DNAcopy']),
#  'acnr': PackageMetadata(name='acnr', version='1.0.0', depends=[], imports=[], linking_to=[], suggests=['R.utils', 'knitr', 'rmarkdown', 'testthat']),
#  'acopula': PackageMetadata(name='acopula', version='0.9.4', depends=[], imports=[], linking_to=[], suggests=['mvtnorm']),
#  'acoRn': PackageMetadata(name='acoRn', version='0.1.0', depends=[], imports=['data.table', 'stringr', 'stringi'], linking_to=[], suggests=['testthat']),
#  'acp': PackageMetadata(name='acp', version='2.1', depends=['tseries', 'quantmod'], imports=[], linking_to=[], suggests=[]),
#  'acro': PackageMetadata(name='acro', version='0.1.6', depends=[], imports=['reticulate', 'admiraldev', 'png'], linking_to=[], suggests=['spelling', 'testthat']),
#  'acroname': PackageMetadata(name='acroname', version='0.1.0', depends=[], imports=['magrittr', 'R.utils', 'dplyr', 'purrr', 'readr', 'stringr', 'hunspell'], linking_to=[], suggests=['testthat']),
#  'acss': PackageMetadata(name='acss', version='0.3-2', depends=['acss.data'], imports=['zoo'], linking_to=[], suggests=['effects', 'lattice', 'knitr', 'rmarkdown']),
#  'acss.data': PackageMetadata(name='acss.data', version='1.2', depends=[], imports=[], linking_to=[], suggests=[]),
#  'ACSSpack': PackageMetadata(name='ACSSpack', version='1.0.0.2', depends=[], imports=['stats', 'HDCI', 'MASS', 'extraDistr'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=[]),
#  'ACSWR': PackageMetadata(name='ACSWR', version='1.0', depends=[], imports=['MASS'], linking_to=[], suggests=[]),
#  'act': PackageMetadata(name='act', version='1.3.1', depends=[], imports=['methods', 'stringr', 'stringi', 'tools', 'textutils', 'utils', 'progress', 'XML', 'xml2', 'openxlsx'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'ACTCD': PackageMetadata(name='ACTCD', version='1.3-0', depends=['R.methodsS3'], imports=['GDINA', 'stats', 'utils'], linking_to=[], suggests=[]),
#  'ActCR': PackageMetadata(name='ActCR', version='0.3.0', depends=[], imports=['zoo', 'cosinor', 'cosinor2', 'dplyr', 'minpack.lm'], linking_to=[], suggests=[]),
#  'actel': PackageMetadata(name='actel', version='1.3.0', depends=[], imports=['circular', 'data.table', 'DiagrammeR', 'DiagrammeRsvg', 'fasttime', 'ggplot2', 'graphics', 'grDevices', 'knitr', 'readr', 'reshape2', 'rmarkdown', 'rsvg', 'scales', 'stats', 'stringi', 'stringr', 'svglite', 'utils'], linking_to=[], suggests=['gdistance', 'gWidgets2', 'gWidgets2tcltk', 'raster', 'sp', 'sf', 'terra', 'testthat']),
#  'ActFrag': PackageMetadata(name='ActFrag', version='0.1.1', depends=[], imports=['accelerometry', 'dplyr', 'ineq', 'survival', 'stats', 'tidyr'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'actfts': PackageMetadata(name='actfts', version='0.3.0', depends=[], imports=['openxlsx', 'plotly', 'reactable', 'tseries', 'xts', 'stats', 'forecast', 'lifecycle'], linking_to=[], suggests=['dplyr', 'knitr', 'rmarkdown', 'testthat']),
#  'actilifecounts': PackageMetadata(name='actilifecounts', version='1.1.1', depends=[], imports=['gsignal', 'pracma', 'GGIRread'], linking_to=[], suggests=['covr', 'testthat']),
#  'ActiSleep': PackageMetadata(name='ActiSleep', version='0.2.2', depends=[], imports=['dplyr', 'stringr', 'lubridate', 'accelerometry', 'DBI', 'RSQLite', 'lazyeval', 'methods', 'utils', 'tibble'], linking_to=[], suggests=[]),
#  'activAnalyzer': PackageMetadata(name='activAnalyzer', version='2.1.2', depends=[], imports=['assertthat', 'dbplyr', 'dplyr', 'flextable', 'forcats', 'ggplot2', 'golem', 'hms', 'lubridate', 'magrittr', 'modelr', 'patchwork', 'PhysicalActivity', 'plyr', 'reactable', 'rmarkdown', 'RSQLite', 'shiny', 'shinycssloaders', 'shinydashboard', 'shinydashboardPlus', 'shinyFeedback', 'shinyjs', 'stringr', 'tidyr', 'zoo'], linking_to=[], suggests=['covr', 'knitr', 'spelling', 'testthat', 'processx', 'globals', 'config', 'tidyselect', 'DBI', 'htmltools', 'officer', 'pkgload', 'scales', 'tibble', 'rlang', 'tinytex', 'shinytest2', 'pkgdown', 'callr']),
#  'activatr': PackageMetadata(name='activatr', version='0.2.1', depends=[], imports=['dplyr', 'geosphere', 'ggmap', 'glue', 'httr', 'lubridate', 'rlang', 'tibble', 'slider', 'xml2'], linking_to=[], suggests=['covr', 'ggplot2', 'knitr', 'mockery', 'rmarkdown', 'roxygen2', 'sf', 'testthat']),
#  'ActiveDriver': PackageMetadata(name='ActiveDriver', version='1.0.0', depends=[], imports=['stats', 'parallel', 'MASS'], linking_to=[], suggests=[]),
#  'activegp': PackageMetadata(name='activegp', version='1.1.1', depends=[], imports=['Rcpp', 'hetGP', 'lhs', 'numDeriv', 'methods', 'MASS', 'RcppProgress'], linking_to=['Rcpp', 'RcppArmadillo', 'RcppProgress'], suggests=['testthat']),
#  'ActiveLearning4SPM': PackageMetadata(name='ActiveLearning4SPM', version='0.1.0', depends=[], imports=['Rcpp', 'Rfast', 'mvnfast', 'rrcov', 'caTools', 'abind', 'pROC', 'stats'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=['covr', 'testthat']),
#  'ActivePathways': PackageMetadata(name='ActivePathways', version='2.0.6', depends=[], imports=['data.table', 'ggplot2'], linking_to=[], suggests=['testthat', 'knitr', 'rmarkdown', 'RColorBrewer']),
#  'activity': PackageMetadata(name='activity', version='1.3.4', depends=['methods'], imports=['pbapply'], linking_to=[], suggests=[]),
#  'activityCounts': PackageMetadata(name='activityCounts', version='0.2.1', depends=[], imports=['seewave', 'signal', 'tibble', 'lubridate', 'magrittr'], linking_to=[], suggests=['knitr', 'rmarkdown', 'ggplot2', 'testthat']),
#  'ActivityIndex': PackageMetadata(name='ActivityIndex', version='0.3.7', depends=[], imports=['matrixStats', 'data.table', 'utils', 'R.utils'], linking_to=[], suggests=['knitr', 'testthat', 'graphics', 'rmarkdown']),
#  'activPAL': PackageMetadata(name='activPAL', version='0.1.4', depends=[], imports=['dplyr', 'ggplot2', 'tidyr', 'lubridate', 'magrittr', 'methods', 'devtools'], linking_to=[], suggests=['testthat']),
#  'actLifer': PackageMetadata(name='actLifer', version='1.0.0', depends=['dplyr'], imports=[], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat', 'tibble', 'htmltools']),
#  'actogrammr': PackageMetadata(name='actogrammr', version='0.2.3', depends=[], imports=['dplyr', 'ggplot2', 'lubridate', 'readr', 'tidyr'], linking_to=[], suggests=['testthat', 'covr']),
#  'actuar': PackageMetadata(name='actuar', version='3.3-6', depends=[], imports=['stats', 'graphics', 'expint'], linking_to=['expint'], suggests=['MASS']),
#  'actuaRE': PackageMetadata(name='actuaRE', version='0.1.7', depends=['stats', 'methods', 'cplm'], imports=['statmod', 'nlme', 'lme4', 'magrittr', 'data.table', 'ggplot2', 'knitr', 'reformulas'], linking_to=[], suggests=['plyr', 'insuranceData', 'actuar', 'utils', 'lattice', 'minqa', 'rmarkdown', 'dplyr']),
#  'ActuarialM': PackageMetadata(name='ActuarialM', version='0.1.0', depends=[], imports=['stats'], linking_to=[], suggests=[]),
#  'actuaryr': PackageMetadata(name='actuaryr', version='1.1.1', depends=[], imports=['lubridate', 'dplyr', 'magrittr', 'crayon', 'purrr', 'tibble'], linking_to=[], suggests=['testthat', 'knitr', 'rmarkdown']),
#  'actxps': PackageMetadata(name='actxps', version='1.6.1', depends=[], imports=['dplyr', 'ggplot2', 'tibble', 'rlang', 'glue', 'purrr', 'scales', 'gt', 'paletteer', 'recipes', 'generics', 'readr', 'tidyr', 'vctrs', 'clock', 'cli'], linking_to=[], suggests=['knitr', 'RColorBrewer', 'rmarkdown', 'testthat', 'shiny', 'bslib', 'thematic']),
#  'AcuityView': PackageMetadata(name='AcuityView', version='0.1', depends=[], imports=['imager', 'fftwtools', 'plotrix', 'tools', 'grid', 'grDevices', 'graphics'], linking_to=[], suggests=[]),
#  'acumos': PackageMetadata(name='acumos', version='0.4-4', depends=[], imports=['httr', 'jsonlite', 'RProtoBuf', 'Rserve', 'RestRserve', 'yaml'], linking_to=[], suggests=['randomForest', 'testthat', 'callr']),
#  'ACV': PackageMetadata(name='ACV', version='1.0.2', depends=[], imports=['forecast', 'Matrix', 'methods', 'stats'], linking_to=[], suggests=['testthat']),
#  'ACWR': PackageMetadata(name='ACWR', version='0.1.0', depends=[], imports=['r2d3'], linking_to=[], suggests=['testthat']),
#  'ada': PackageMetadata(name='ada', version='2.0-5', depends=['rpart'], imports=[], linking_to=[], suggests=[]),
#  'adabag': PackageMetadata(name='adabag', version='5.1', depends=['rpart', 'caret', 'foreach', 'doParallel'], imports=['methods', 'tidyr', 'dplyr', 'ConsRank'], linking_to=[], suggests=['mlbench']),
#  'adace': PackageMetadata(name='adace', version='1.0.2', depends=[], imports=['reshape2', 'pracma'], linking_to=[], suggests=['testthat', 'cubature', 'MASS']),
#  'adagio': PackageMetadata(name='adagio', version='0.9.2', depends=[], imports=['graphics', 'stats', 'lpSolve'], linking_to=[], suggests=[]),
#  'adaHuber': PackageMetadata(name='adaHuber', version='1.1', depends=[], imports=['Rcpp'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=[]),
#  'adamethods': PackageMetadata(name='adamethods', version='1.2.1', depends=[], imports=['Anthropometry', 'archetypes', 'FNN', 'foreach', 'graphics', 'nnls', 'parallel', 'stats', 'tolerance', 'univOutl', 'utils'], linking_to=[], suggests=['doParallel', 'fda']),
#  'adana': PackageMetadata(name='adana', version='1.1.0', depends=[], imports=['stats', 'optimx', 'ROI', 'ROI.plugin.optimx'], linking_to=[], suggests=[]),
#  'AdapDiscom': PackageMetadata(name='AdapDiscom', version='1.0.0', depends=[], imports=['softImpute', 'Matrix', 'scout', 'robustbase'], linking_to=[], suggests=['knitr', 'rmarkdown', 'MASS']),
#  'adaplots': PackageMetadata(name='adaplots', version='0.1.0', depends=[], imports=['ggplot2'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'AdapSamp': PackageMetadata(name='AdapSamp', version='1.1.1', depends=[], imports=['pracma', 'stats'], linking_to=[], suggests=[]),
#  'adapt3': PackageMetadata(name='adapt3', version='1.0.1', depends=[], imports=['Rcpp', 'lefko3', 'methods', 'rlang', 'grDevices'], linking_to=['Rcpp', 'RcppArmadillo', 'BH', 'lefko3'], suggests=['knitr', 'rmarkdown']),
#  'adapt4pv': PackageMetadata(name='adapt4pv', version='0.2-3', depends=['Matrix', 'glmnet'], imports=['speedglm', 'xgboost', 'doParallel', 'foreach'], linking_to=[], suggests=[]),
#  'adaptalint': PackageMetadata(name='adaptalint', version='0.2.4', depends=[], imports=['dplyr', 'lintr', 'purrr'], linking_to=[], suggests=['devtools', 'git2r', 'testthat']),
#  'adaptDiag': PackageMetadata(name='adaptDiag', version='0.1.0', depends=[], imports=['doParallel', 'extraDistr', 'foreach', 'parallel', 'pbmcapply', 'stats'], linking_to=[], suggests=['rmarkdown', 'knitr', 'testthat', 'VGAM', 'covr']),
#  'AdaptGauss': PackageMetadata(name='AdaptGauss', version='1.6', depends=[], imports=['Rcpp', 'shiny', 'pracma', 'methods', 'DataVisualizations', 'plotly'], linking_to=['Rcpp'], suggests=['mclust', 'grid', 'foreach', 'dqrng', 'parallelDist', 'knitr', 'rmarkdown', 'reshape2', 'ggplot2']),
#  'AdaptiveBoxplot': PackageMetadata(name='AdaptiveBoxplot', version='0.1.1', depends=[], imports=[], linking_to=[], suggests=[]),
#  'adaptiveGPCA': PackageMetadata(name='adaptiveGPCA', version='0.1.3', depends=[], imports=['ape', 'ggplot2', 'shiny', 'phyloseq'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'adaptivetau': PackageMetadata(name='adaptivetau', version='2.3-2', depends=[], imports=[], linking_to=[], suggests=[]),
#  'adaptIVPT': PackageMetadata(name='adaptIVPT', version='1.1.0', depends=[], imports=['Rcpp', 'rgl'], linking_to=['Rcpp', 'RcppArmadillo', 'RcppProgress'], suggests=['knitr', 'rmarkdown']),
#  'adaptMCMC': PackageMetadata(name='adaptMCMC', version='1.5', depends=['parallel', 'coda', 'Matrix'], imports=['ramcmc'], linking_to=[], suggests=[]),
#  'adaptMT': PackageMetadata(name='adaptMT', version='1.0.0', depends=[], imports=['methods'], linking_to=[], suggests=['glmnet', 'HDtweedie', 'mgcv', 'splines', 'testthat', 'knitr', 'rmarkdown', 'dplyr']),
#  'adaptr': PackageMetadata(name='adaptr', version='1.4.0', depends=[], imports=['stats', 'parallel', 'utils'], linking_to=[], suggests=['ggplot2', 'covr', 'rmarkdown', 'knitr', 'testthat', 'vdiffr']),
#  'ADAPTS': PackageMetadata(name='ADAPTS', version='1.0.22', depends=[], imports=['missForest', 'e1071', 'ComICS', 'pheatmap', 'doParallel', 'utils', 'quantmod', 'preprocessCore', 'pcaMethods', 'foreach', 'nnls', 'ranger'], linking_to=[], suggests=['R.rsp', 'DeconRNASeq', 'WGCNA']),
#  'adaptsmoFMRI': PackageMetadata(name='adaptsmoFMRI', version='1.2', depends=[], imports=['methods', 'stats', 'spatstat', 'spatstat.geom', 'Matrix', 'coda', 'mvtnorm', 'MCMCpack', 'parallel'], linking_to=[], suggests=[]),
#  'adaptTest': PackageMetadata(name='adaptTest', version='1.2', depends=[], imports=['graphics', 'lattice', 'stats'], linking_to=[], suggests=[]),
#  'adaR': PackageMetadata(name='adaR', version='0.3.4', depends=[], imports=['Rcpp', 'triebeard'], linking_to=['Rcpp'], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'adas.utils': PackageMetadata(name='adas.utils', version='1.3.0', depends=[], imports=['dplyr', 'gghalfnorm', 'ggplot2', 'glue', 'grDevices', 'lubridate', 'magrittr', 'purrr', 'readr', 'rlang', 'scales', 'stats', 'stringr', 'tibble', 'tidyr', 'utils', 'vctrs'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat', 'tidyverse']),
#  'AdaSampling': PackageMetadata(name='AdaSampling', version='1.3', depends=[], imports=['caret', 'class', 'e1071', 'stats', 'MASS'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'adass': PackageMetadata(name='adass', version='1.0.1', depends=[], imports=['fda', 'parallel', 'matrixcalc', 'SparseM', 'mvtnorm', 'Rfast', 'plot3D'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'adbcdrivermanager': PackageMetadata(name='adbcdrivermanager', version='0.21.0', depends=[], imports=['nanoarrow'], linking_to=[], suggests=['testthat', 'withr']),
#  'adbcpostgresql': PackageMetadata(name='adbcpostgresql', version='0.21.0', depends=[], imports=['adbcdrivermanager'], linking_to=[], suggests=['nanoarrow', 'testthat']),
#  'adbcsqlite': PackageMetadata(name='adbcsqlite', version='0.21.0', depends=[], imports=['adbcdrivermanager'], linking_to=[], suggests=['nanoarrow', 'testthat']),
#  'adbi': PackageMetadata(name='adbi', version='0.1.2', depends=[], imports=['DBI', 'methods', 'adbcdrivermanager', 'nanoarrow'], linking_to=[], suggests=['testthat', 'covr', 'DBItest', 'adbcsqlite', 'withr', 'bit64', 'utils', 'arrow']),
#  'adc': PackageMetadata(name='adc', version='1.0.0', depends=[], imports=['runner', 'stats'], linking_to=[], suggests=['covr', 'testthat']),
#  'adcontabil': PackageMetadata(name='adcontabil', version='1.1.8', depends=[], imports=['dplyr', 'magrittr', 'stringi', 'data.table'], linking_to=[], suggests=[]),
#  'ADCT': PackageMetadata(name='ADCT', version='0.1.0', depends=[], imports=['stats', 'mvtnorm'], linking_to=[], suggests=['clinfun', 'gsDesign']),
#  'add2ggplot': PackageMetadata(name='add2ggplot', version='0.3.0', depends=[], imports=['ggplot2', 'magrittr', 'RColorBrewer', 'magick', 'zeallot'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'addhaz': PackageMetadata(name='addhaz', version='0.5', depends=['stats', 'boot', 'Matrix', 'MASS'], imports=[], linking_to=[], suggests=[]),
#  'addhazard': PackageMetadata(name='addhazard', version='1.1.0', depends=[], imports=['ahaz', 'survival', 'rootSolve'], linking_to=[], suggests=[]),
#  'addinsJoaoMelo': PackageMetadata(name='addinsJoaoMelo', version='0.1.0', depends=[], imports=['dplyr', 'stringr', 'rstudioapi', 'purrr'], linking_to=[], suggests=[]),
#  'addinslist': PackageMetadata(name='addinslist', version='0.5.0', depends=[], imports=['curl', 'remotes', 'DT', 'miniUI', 'shiny', 'shinyjs', 'rappdirs', 'rmarkdown', 'rvest', 'utils', 'xml2'], linking_to=[], suggests=[]),
#  'addinsOutline': PackageMetadata(name='addinsOutline', version='0.1.6', depends=[], imports=['shiny', 'miniUI', 'rstudioapi', 'shinyFiles', 'stringr', 'dplyr', 'tibble', 'yaml', 'rmarkdown', 'fs', 'DT'], linking_to=[], suggests=['knitr']),
#  'additive': PackageMetadata(name='additive', version='1.0.1', depends=['mgcv', 'parsnip'], imports=['dplyr', 'purrr', 'rlang', 'stats', 'tibble', 'utils'], linking_to=[], suggests=['covr', 'devtools', 'knitr', 'recipes', 'rmarkdown', 'roxygen2', 'spelling', 'testthat', 'workflows']),
#  'additivityTests': PackageMetadata(name='additivityTests', version='1.1-4.2', depends=[], imports=[], linking_to=[], suggests=['knitr']),
#  'addreg': PackageMetadata(name='addreg', version='3.0', depends=[], imports=['splines', 'combinat', 'glm2', 'turboEM'], linking_to=[], suggests=[]),
#  'ADDT': PackageMetadata(name='ADDT', version='2.0', depends=['nlme', 'Matrix', 'coneproj'], imports=[], linking_to=[], suggests=[]),
#  'ade4': PackageMetadata(name='ade4', version='1.7-23', depends=[], imports=['graphics', 'grDevices', 'methods', 'stats', 'utils', 'MASS', 'pixmap', 'sp', 'Rcpp'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=['ade4TkGUI', 'adegraphics', 'adephylo', 'adespatial', 'ape', 'CircStats', 'deldir', 'lattice', 'spdep', 'splancs', 'waveslim', 'progress', 'foreach', 'parallel', 'doParallel', 'iterators', 'knitr', 'rmarkdown']),
#  'ade4TkGUI': PackageMetadata(name='ade4TkGUI', version='0.3.4', depends=['ade4', 'adegraphics'], imports=['graphics', 'grDevices', 'lattice', 'stats', 'tcltk', 'utils'], linking_to=[], suggests=['pixmap', 'tkrplot']),
#  'adea': PackageMetadata(name='adea', version='1.5.2', depends=['methods', 'rmarkdown', 'ROI.plugin.glpk', 'ROI.plugin.lpsolve', 'ROI.plugin.symphony'], imports=['combinat', 'graphics', 'knitr', 'lpSolveAPI', 'parallel', 'parallelly', 'ROI', 'slam'], linking_to=[], suggests=['testthat']),
#  'adegenet': PackageMetadata(name='adegenet', version='2.1.11', depends=['methods', 'ade4'], imports=['utils', 'stats', 'grDevices', 'MASS', 'igraph', 'ape', 'shiny', 'ggplot2', 'seqinr', 'parallel', 'boot', 'reshape2', 'dplyr', 'vegan'], linking_to=[], suggests=['adespatial', 'pegas', 'hierfstat', 'maps', 'spdep', 'interp', 'splancs', 'poppr', 'testthat']),
#  'adegraphics': PackageMetadata(name='adegraphics', version='1.0-22', depends=[], imports=['ade4', 'graphics', 'grid', 'KernSmooth', 'lattice', 'latticeExtra', 'methods', 'RColorBrewer', 'sp', 'stats'], linking_to=[], suggests=['car', 'Guerry', 'knitr', 'markdown', 'pixmap', 'rmarkdown', 'spdep', 'splancs']),
#  'adehabitatHR': PackageMetadata(name='adehabitatHR', version='0.4.22', depends=['sp', 'methods', 'ade4', 'adehabitatMA', 'adehabitatLT'], imports=['graphics', 'grDevices', 'stats'], linking_to=[], suggests=['tkrplot', 'MASS', 'sf', 'deldir']),
#  'adehabitatHS': PackageMetadata(name='adehabitatHS', version='0.3.18', depends=['sp', 'methods', 'ade4', 'adehabitatMA', 'adehabitatHR'], imports=['graphics', 'grDevices', 'stats'], linking_to=[], suggests=['tkrplot', 'MASS']),
#  'adehabitatLT': PackageMetadata(name='adehabitatLT', version='0.3.29', depends=['sp', 'methods', 'ade4', 'adehabitatMA', 'stats'], imports=['graphics', 'grDevices', 'utils'], linking_to=[], suggests=['tkrplot', 'MASS']),
#  'adehabitatMA': PackageMetadata(name='adehabitatMA', version='0.3.17', depends=['sp', 'methods'], imports=['utils', 'graphics', 'grDevices', 'stats'], linking_to=[], suggests=['tkrplot', 'MASS']),
#  'adelie': PackageMetadata(name='adelie', version='1.0.8', depends=[], imports=['Matrix', 'r2r', 'Rcpp', 'methods', 'stringr', 'utils'], linking_to=['Rcpp', 'RcppEigen'], suggests=['ggplot2', 'gridExtra', 'testthat', 'knitr', 'rmarkdown']),
#  'adephylo': PackageMetadata(name='adephylo', version='1.1-17', depends=['methods', 'ade4'], imports=['phylobase', 'ape', 'adegenet'], linking_to=[], suggests=[]),
#  'adepro': PackageMetadata(name='adepro', version='4.2.7', depends=['shinyBS', 'seriation'], imports=['graphics', 'MASS', 'V8', 'forcats', 'here', 'utils', 'shinyjs', 'shiny', 'audio', 'shape', 'Cairo', 'dplyr', 'readr', 'rlang', 'tidyr', 'haven', 'stats', 'shinyWidgets', 'DT'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'adept': PackageMetadata(name='adept', version='1.2', depends=[], imports=['dplyr', 'magrittr', 'dvmisc', 'parallel', 'pracma'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat', 'ggplot2', 'lubridate', 'reshape2', 'gridExtra', 'spelling', 'cluster', 'adeptdata', 'covr']),
#  'adeptdata': PackageMetadata(name='adeptdata', version='1.1', depends=[], imports=[], linking_to=[], suggests=['spelling']),
#  'AdequacyModel': PackageMetadata(name='AdequacyModel', version='2.0.0', depends=[], imports=['methods', 'stats', 'graphics'], linking_to=[], suggests=[]),
#  'ADER': PackageMetadata(name='ADER', version='1.5', depends=[], imports=[], linking_to=[], suggests=[]),
#  'adespatial': PackageMetadata(name='adespatial', version='0.3-28', depends=[], imports=['ade4', 'adegraphics', 'adephylo', 'sp', 'spdep', 'lattice', 'methods', 'grDevices', 'graphics', 'MASS', 'stats', 'utils', 'shiny', 'vegan'], linking_to=[], suggests=['knitr', 'ape', 'rmarkdown', 'betapart']),
#  'adestr': PackageMetadata(name='adestr', version='1.0.0', depends=['adoptr'], imports=['methods', 'stats', 'grDevices', 'cubature', 'ggplot2', 'ggpubr', 'scales', 'latex2exp', 'forcats', 'future.apply', 'progressr', 'Rdpack'], linking_to=[], suggests=['covr', 'knitr', 'rmarkdown', 'testthat', 'microbenchmark']),
#  'adfExplorer': PackageMetadata(name='adfExplorer', version='2.1.0', depends=[], imports=['methods', 'vctrs'], linking_to=['cpp11'], suggests=['AmigaFFH', 'knitr', 'ProTrackR2', 'rmarkdown', 'testthat']),
#  'adformR': PackageMetadata(name='adformR', version='0.1.0', depends=[], imports=['jsonlite'], linking_to=[], suggests=['knitr', 'rmarkdown', 'dplyr', 'ggplot2', 'tidyr', 'curl']),
#  'ADGofTest': PackageMetadata(name='ADGofTest', version='0.3', depends=[], imports=[], linking_to=[], suggests=[]),
#  'adheRenceRX': PackageMetadata(name='adheRenceRX', version='1.0.0', depends=[], imports=['Rcpp', 'anytime', 'tidyr', 'dplyr', 'purrr', 'lubridate', 'rlang'], linking_to=['Rcpp'], suggests=['testthat', 'spelling']),
#  'AdhereR': PackageMetadata(name='AdhereR', version='0.8.1', depends=[], imports=['lubridate', 'parallel', 'data.table', 'rsvg', 'jpeg', 'png', 'webp', 'methods'], linking_to=[], suggests=['rmarkdown', 'knitr', 'R.rsp', 'base64', 'viridisLite', 'AdhereRViz']),
#  'AdhereRViz': PackageMetadata(name='AdhereRViz', version='0.2.1', depends=[], imports=['AdhereR', 'data.table', 'manipulate', 'shiny', 'shinyWidgets', 'shinyjs', 'V8', 'colourpicker', 'viridisLite', 'highlight', 'clipr', 'knitr', 'DBI', 'RMariaDB', 'RSQLite'], linking_to=[], suggests=['rmarkdown', 'readODS', 'readxl', 'haven', 'R.rsp']),
#  'adimpro': PackageMetadata(name='adimpro', version='0.9.7.2', depends=[], imports=['awsMethods', 'grDevices', 'methods'], linking_to=[], suggests=[]),
#  'AdIsMF': PackageMetadata(name='AdIsMF', version='0.1.1', depends=[], imports=['AICcmodavg', 'ggplot2', 'nls2', 'stats'], linking_to=[], suggests=[]),
#  'adiv': PackageMetadata(name='adiv', version='2.2.1', depends=[], imports=['ade4', 'adegraphics', 'ape', 'cluster', 'graphics', 'grDevices', 'lpSolve', 'methods', 'phylobase', 'phytools', 'rgl', 'stats', 'utils'], linking_to=[], suggests=[]),
#  'adjclust': PackageMetadata(name='adjclust', version='0.6.11', depends=[], imports=['stats', 'graphics', 'grDevices', 'Rcpp', 'Matrix', 'sparseMatrixStats', 'methods', 'utils', 'capushe', 'ggplot2', 'dendextend', 'rlang'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=['knitr', 'testthat', 'rmarkdown', 'rioja', 'HiTC', 'snpStats', 'BiocGenerics']),
#  'adjROC': PackageMetadata(name='adjROC', version='0.3', depends=[], imports=['ROCit', 'ggplot2', 'boot', 'yardstick'], linking_to=[], suggests=[]),
#  'adjSURVCI': PackageMetadata(name='adjSURVCI', version='1.0', depends=[], imports=['Rcpp', 'survival'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=[]),
#  'adjustedcranlogs': PackageMetadata(name='adjustedcranlogs', version='0.1.0', depends=[], imports=['cranlogs', 'xml2', 'lubridate', 'dplyr', 'rvest'], linking_to=[], suggests=[]),
#  'adjustedCurves': PackageMetadata(name='adjustedCurves', version='0.11.3', depends=[], imports=['R.utils', 'doParallel', 'doRNG', 'dplyr', 'foreach', 'rlang', 'survival'], linking_to=[], suggests=['MASS', 'Matching', 'WeightIt', 'cmprsk', 'eventglm', 'geepack', 'ggplot2', 'knitr', 'mice', 'nnet', 'pammtools', 'pec', 'prodlim', 'riskRegression', 'rmarkdown', 'testthat', 'tidyr', 'ggpp', 'vdiffr', 'covr', 'data.table', 'numDeriv', 'cowplot']),
#  'adklakedata': PackageMetadata(name='adklakedata', version='0.6.4', depends=[], imports=['httr', 'rappdirs', 'tibble'], linking_to=[], suggests=['sf', 'testthat']),
#  'adlift': PackageMetadata(name='adlift', version='1.4-6', depends=['EbayesThresh'], imports=[], linking_to=[], suggests=[]),
#  'ADLP': PackageMetadata(name='ADLP', version='0.1.0', depends=[], imports=['methods'], linking_to=[], suggests=['knitr', 'tidyverse', 'SynthETIC']),
#  'admiral': PackageMetadata(name='admiral', version='1.3.1', depends=[], imports=['admiraldev', 'cli', 'dplyr', 'hms', 'lifecycle', 'lubridate', 'magrittr', 'purrr', 'rlang', 'stringr', 'tidyr', 'tidyselect'], linking_to=[], suggests=['diffdf', 'DT', 'htmltools', 'knitr', 'methods', 'pharmaversesdtm', 'reactable', 'readxl', 'rmarkdown', 'testthat', 'tibble', 'withr']),
#  'admiral.test': PackageMetadata(name='admiral.test', version='0.7.0', depends=[], imports=[], linking_to=[], suggests=['devtools', 'lintr', 'pkgdown', 'testthat', 'knitr', 'rmarkdown', 'roxygen2', 'spelling', 'usethis', 'covr']),
#  'admiraldev': PackageMetadata(name='admiraldev', version='1.3.1', depends=[], imports=['cli', 'dplyr', 'glue', 'lifecycle', 'lubridate', 'purrr', 'rlang', 'roxygen2', 'stringr', 'tidyr', 'tidyselect', 'withr'], linking_to=[], suggests=['diffdf', 'DT', 'htmltools', 'knitr', 'methods', 'pkgdown', 'rmarkdown', 'spelling', 'testthat']),
#  'admiralmetabolic': PackageMetadata(name='admiralmetabolic', version='0.2.0', depends=[], imports=['admiral', 'admiraldev', 'cli', 'dplyr', 'lifecycle', 'lubridate', 'magrittr', 'purrr', 'rlang', 'stringr', 'tidyselect'], linking_to=[], suggests=['diffdf', 'DT', 'htmltools', 'knitr', 'methods', 'pharmaversesdtm', 'rmarkdown', 'testthat', 'tibble', 'usethis']),
#  'admiralneuro': PackageMetadata(name='admiralneuro', version='0.1.0', depends=[], imports=['admiral', 'admiraldev', 'cli', 'dplyr', 'hms', 'lifecycle', 'lubridate', 'magrittr', 'purrr', 'rlang', 'stringr', 'tibble', 'tidyr', 'tidyselect'], linking_to=[], suggests=['diffdf', 'DT', 'htmltools', 'knitr', 'metatools', 'methods', 'pharmaversesdtm', 'reactable', 'readxl', 'rmarkdown', 'testthat']),
#  'admiralonco': PackageMetadata(name='admiralonco', version='1.3.0', depends=[], imports=['admiral', 'admiraldev', 'dplyr', 'lifecycle', 'lubridate', 'magrittr', 'rlang', 'tidyselect'], linking_to=[], suggests=['pharmaversesdtm', 'pharmaverseadam', 'devtools', 'diffdf', 'lintr', 'pkgdown', 'testthat', 'knitr', 'methods', 'miniUI', 'rmarkdown', 'roxygen2', 'spelling', 'stringr', 'tibble', 'usethis', 'covr', 'DT', 'metatools', 'cli', 'gt']),
#  'admiralophtha': PackageMetadata(name='admiralophtha', version='1.3.0', depends=[], imports=['admiral', 'admiraldev', 'dplyr', 'hms', 'lifecycle', 'lubridate', 'magrittr', 'purrr', 'rlang', 'stringr', 'tidyr', 'tidyselect'], linking_to=[], suggests=['devtools', 'diffdf', 'knitr', 'lintr', 'methods', 'miniUI', 'pharmaversesdtm', 'pkgdown', 'rmarkdown', 'roxygen2', 'spelling', 'testthat', 'tibble', 'usethis']),
#  'admiralpeds': PackageMetadata(name='admiralpeds', version='0.2.1', depends=[], imports=['admiral', 'admiraldev', 'cli', 'dplyr', 'magrittr', 'purrr', 'rlang', 'tidyselect', 'zoo'], linking_to=[], suggests=['knitr', 'lubridate', 'pharmaversesdtm', 'rmarkdown', 'stringr', 'testthat', 'tibble']),
#  'admiralvaccine': PackageMetadata(name='admiralvaccine', version='0.5.0', depends=[], imports=['admiral', 'admiraldev', 'assertthat', 'dplyr', 'hms', 'lifecycle', 'lubridate', 'magrittr', 'purrr', 'rlang', 'stringr', 'tidyr', 'tidyselect'], linking_to=[], suggests=['covr', 'devtools', 'diffdf', 'DT', 'knitr', 'lintr', 'metatools', 'methods', 'miniUI', 'pharmaversesdtm', 'pkgdown', 'rmarkdown', 'roxygen2', 'spelling', 'testthat', 'tibble', 'usethis']),
#  'admisc': PackageMetadata(name='admisc', version='0.39', depends=[], imports=['methods'], linking_to=[], suggests=['QCA']),
#  'AdMit': PackageMetadata(name='AdMit', version='2.1.9', depends=['mvtnorm'], imports=[], linking_to=[], suggests=['coda']),
#  'admix': PackageMetadata(name='admix', version='2.5.1', depends=[], imports=['base', 'cubature', 'EnvStats', 'fdrtool', 'graphics', 'Iso', 'MASS', 'orthopolynom', 'pracma', 'Rcpp', 'Rdpack', 'stats', 'utils'], linking_to=['Rcpp'], suggests=['doParallel', 'doRNG', 'evd', 'flexsurv', 'foreach', 'gridExtra', 'knitr', 'lattice', 'logitnorm', 'plyr', 'reshape2', 'rmarkdown', 'rmutil', 'testthat']),
#  'admixr': PackageMetadata(name='admixr', version='0.9.2', depends=[], imports=['dplyr', 'magrittr', 'readr', 'stringr', 'tibble', 'stats', 'rlang', 'utils'], linking_to=[], suggests=['glue', 'ggplot2', 'testthat', 'forcats', 'tidyr', 'knitr', 'rmarkdown']),
#  'ADMM': PackageMetadata(name='ADMM', version='0.3.4', depends=[], imports=['Rcpp', 'Matrix', 'Rdpack', 'stats', 'doParallel', 'foreach', 'parallel', 'utils'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=[]),
#  'admmDensestSubmatrix': PackageMetadata(name='admmDensestSubmatrix', version='0.1.0', depends=[], imports=['Rdpack', 'utils', 'stats'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'admtools': PackageMetadata(name='admtools', version='0.6.0', depends=[], imports=['ape'], linking_to=[], suggests=['FossilSim', 'knitr', 'rmarkdown', 'spelling', 'testthat']),
#  'adnuts': PackageMetadata(name='adnuts', version='1.1.2', depends=['snowfall'], imports=['ellipse', 'rstan', 'R2admb', 'ggplot2', 'rlang'], linking_to=[], suggests=['shinystan', 'matrixcalc', 'stats', 'knitr', 'TMB', 'rmarkdown', 'withr', 'testthat']),
#  'adobeanalyticsr': PackageMetadata(name='adobeanalyticsr', version='0.5.0', depends=[], imports=['assertthat', 'jsonlite', 'dplyr', 'stringr', 'purrr', 'httr', 'tidyr', 'rlang', 'lubridate', 'ggplot2', 'scales', 'R6', 'jose', 'openssl', 'lifecycle', 'glue', 'vctrs', 'progress', 'memoise', 'utils', 'httr2'], linking_to=[], suggests=['knitr', 'testthat', 'rmarkdown']),
#  'adoptr': PackageMetadata(name='adoptr', version='1.1.1', depends=[], imports=['nloptr', 'methods', 'glue'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat', 'covr', 'rpact', 'vdiffr', 'pwr', 'dplyr', 'ggplot2', 'tidyr', 'gridExtra', 'bookdown']),
#  'ADP': PackageMetadata(name='ADP', version='0.1.6', depends=[], imports=[], linking_to=[], suggests=[]),
#  'ADPclust': PackageMetadata(name='ADPclust', version='0.7', depends=[], imports=['dplyr', 'cluster', 'fields', 'knitr'], linking_to=[], suggests=['rmarkdown', 'testthat']),
#  'ADPF': PackageMetadata(name='ADPF', version='0.0.1', depends=['stats', 'utils'], imports=[], linking_to=[], suggests=[]),
#  'adplots': PackageMetadata(name='adplots', version='0.1.0', depends=[], imports=['ggplot2'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'adproclus': PackageMetadata(name='adproclus', version='2.0.0', depends=[], imports=['checkmate', 'corrplot', 'ggplot2', 'ggrepel', 'gtools', 'igraph', 'matrixStats', 'multichull', 'NMFN', 'qgraph', 'readr', 'rlang', 'scales', 'stats', 'tidyr', 'withr'], linking_to=[], suggests=['testthat']),
#  'adpss': PackageMetadata(name='adpss', version='0.1.2', depends=[], imports=['Rcpp'], linking_to=['Rcpp'], suggests=['knitr', 'rmarkdown']),
#  'adsDataHubR': PackageMetadata(name='adsDataHubR', version='0.1.1', depends=[], imports=['httr', 'jsonlite', 'lubridate'], linking_to=[], suggests=[]),
#  'ADSIHT': PackageMetadata(name='ADSIHT', version='0.2.1', depends=[], imports=['Matrix', 'mvnfast', 'Rcpp', 'purrr', 'snowfall'], linking_to=['Rcpp', 'RcppEigen'], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'AdsorpR': PackageMetadata(name='AdsorpR', version='0.1.0', depends=[], imports=['ggplot2', 'stats'], linking_to=[], suggests=['testthat', 'knitr', 'rmarkdown']),
#  'adsoRptionCMF': PackageMetadata(name='adsoRptionCMF', version='0.1.1', depends=[], imports=['nls2', 'stats', 'Metrics', 'ggplot2', 'boot'], linking_to=[], suggests=['testthat']),
#  'adsoRptionCV': PackageMetadata(name='adsoRptionCV', version='0.1.0', depends=[], imports=['stats', 'nls2', 'graphics'], linking_to=[], suggests=['testthat']),
#  'adsoRptionMCMC': PackageMetadata(name='adsoRptionMCMC', version='0.1.0', depends=[], imports=['MCMCpack', 'coda', 'stats', 'graphics'], linking_to=[], suggests=['testthat']),
#  'ADTSA': PackageMetadata(name='ADTSA', version='1.0.1', depends=[], imports=[], linking_to=[], suggests=[]),
# ...
#  'AutoStepwiseGLM': PackageMetadata(name='AutoStepwiseGLM', version='0.2.0', depends=['caret', 'formula.tools'], imports=[], linking_to=[], suggests=[]),
#  'autostsm': PackageMetadata(name='autostsm', version='3.1.5', depends=[], imports=['maxLik', 'forecast', 'lubridate', 'ggplot2', 'gridExtra', 'strucchange', 'foreach', 'doSNOW', 'parallel', 'lmtest', 'ggrepel', 'progress', 'sandwich', 'data.table', 'kalmanfilter'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'autotab': PackageMetadata(name='autotab', version='0.1.1', depends=[], imports=['keras', 'magrittr', 'R6', 'reticulate', 'tensorflow'], linking_to=[], suggests=['caret']),
#  'autotesteR': PackageMetadata(name='autotesteR', version='0.1.7', depends=[], imports=['car', 'crayon', 'dplyr', 'FSA', 'ggplot2', 'multcompView', 'nortest', 'stats', 'utils'], linking_to=[], suggests=[]),
#  'autothresholdr': PackageMetadata(name='autothresholdr', version='1.4.3', depends=[], imports=['checkmate', 'ijtiff', 'magrittr', 'purrr', 'Rcpp', 'rlang', 'stats', 'strex', 'stringr'], linking_to=['Rcpp'], suggests=['covr', 'dplyr', 'ggplot2', 'knitr', 'rmarkdown', 'spelling', 'testthat', 'utils']),
#  'AutoTransQF': PackageMetadata(name='AutoTransQF', version='0.1.3', depends=[], imports=['VGAM', 'matlab2r', 'moments', 'stats'], linking_to=[], suggests=['nortest']),
#  'autoTS': PackageMetadata(name='autoTS', version='0.9.11', depends=[], imports=['rlang', 'prophet', 'dplyr', 'magrittr', 'lubridate', 'tidyr', 'forecast', 'ggplot2', 'RcppRoll', 'shiny', 'shinycssloaders', 'plotly'], linking_to=[], suggests=['knitr', 'rmarkdown', 'stringr']),
#  'autovi': PackageMetadata(name='autovi', version='0.4.1', depends=[], imports=['bandicoot', 'ggplot2', 'stats', 'tibble', 'tools', 'reticulate', 'utils', 'cassowaryr', 'cli'], linking_to=[], suggests=['rmarkdown', 'knitr', 'testthat', 'covr']),
#  'AutoWeatherIndices': PackageMetadata(name='AutoWeatherIndices', version='0.1.0', depends=[], imports=['Hmisc', 'gtools'], linking_to=[], suggests=[]),
#  'AutoWMM': PackageMetadata(name='AutoWMM', version='1.0.2', depends=[], imports=['data.tree', 'DiagrammeR', 'dplyr', 'gtools', 'MASS', 'rlang', 'magrittr', 'tidyselect'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'AuxSurvey': PackageMetadata(name='AuxSurvey', version='1.1', depends=['mgcv', 'rstanarm', 'stats'], imports=['survey', 'gtools', 'coda', 'BART', 'dplyr', 'stringr', 'rlang'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'auxvecLASSO': PackageMetadata(name='auxvecLASSO', version='0.2.0', depends=[], imports=['doParallel', 'parallelly', 'Matrix', 'glmnet', 'stats', 'survey', 'utils', 'pROC', 'crayon'], linking_to=[], suggests=['testthat', 'foreach', 'knitr', 'rmarkdown', 'withr', 'sampling', 'dplyr']),
#  'av': PackageMetadata(name='av', version='0.9.6', depends=[], imports=['graphics'], linking_to=[], suggests=['curl', 'testthat', 'ps', 'ggplot2', 'gapminder']),
#  'available': PackageMetadata(name='available', version='1.1.0', depends=[], imports=['cli', 'clisymbols', 'crayon', 'tidytext', 'desc', 'glue', 'jsonlite', 'memoise', 'SnowballC', 'stringdist', 'tibble', 'yesno'], linking_to=[], suggests=['usethis', 'BiocManager', 'testthat', 'covr']),
#  'avar': PackageMetadata(name='avar', version='0.1.3', depends=[], imports=['Rcpp', 'stats', 'simts'], linking_to=['Rcpp', 'RcppArmadillo'], suggests=['knitr', 'rmarkdown']),
#  'averisk': PackageMetadata(name='averisk', version='1.0.3', depends=[], imports=['MASS'], linking_to=[], suggests=[]),
#  'avesperu': PackageMetadata(name='avesperu', version='0.0.6', depends=[], imports=[], linking_to=[], suggests=['testthat', 'xml2']),
#  'AVGAS': PackageMetadata(name='AVGAS', version='0.1.0', depends=[], imports=['utils', 'Matrix', 'pracma', 'stats', 'dplyr', 'selectiveInference', 'VariableScreening', 'ggplot2'], linking_to=[], suggests=[]),
#  'avidaR': PackageMetadata(name='avidaR', version='1.2.1', depends=[], imports=['base64enc', 'xml2', 'httr', 'dplyr', 'readr', 'tidyr', 'tibble', 'circlize', 'RColorBrewer', 'R6', 'curl'], linking_to=[], suggests=['testthat']),
#  'avilistr': PackageMetadata(name='avilistr', version='0.0.1', depends=[], imports=[], linking_to=[], suggests=['dplyr', 'ggplot2', 'knitr', 'rmarkdown', 'tidyverse', 'testthat']),
#  'AvInertia': PackageMetadata(name='AvInertia', version='0.0.2', depends=[], imports=['pracma', 'readxl', 'ggplot2', 'stringr', 'tidyr', 'ggthemes', 'reshape2'], linking_to=[], suggests=['knitr', 'rmarkdown']),
#  'aVirtualTwins': PackageMetadata(name='aVirtualTwins', version='1.0.1', depends=[], imports=['rpart', 'party', 'methods', 'randomForest', 'stats'], linking_to=[], suggests=['caret', 'knitr', 'rpart.plot', 'rmarkdown', 'e1071']),
#  'avlm': PackageMetadata(name='avlm', version='0.1.0', depends=[], imports=[], linking_to=[], suggests=['testthat']),
#  'avocado': PackageMetadata(name='avocado', version='0.2.0', depends=[], imports=[], linking_to=[], suggests=['dplyr', 'ggplot2', 'knitr', 'quarto']),
#  'avotrex': PackageMetadata(name='avotrex', version='1.3.0', depends=[], imports=['ape', 'doParallel', 'doSNOW', 'dplyr', 'foreach', 'parallel', 'phytools', 'snow', 'stringr', 'tidytree', 'TreeTools', 'utils'], linking_to=[], suggests=['testthat', 'markdown', 'knitr', 'rmarkdown', 'covr']),
#  'avseqmc': PackageMetadata(name='avseqmc', version='1.0.2', depends=[], imports=[], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'awdb': PackageMetadata(name='awdb', version='0.1.3', depends=[], imports=['cli', 'httr2', 'rlang', 'sf'], linking_to=[], suggests=[]),
#  'aweek': PackageMetadata(name='aweek', version='1.0.3', depends=[], imports=[], linking_to=[], suggests=['testthat', 'stats', 'roxygen2', 'knitr', 'rmarkdown', 'covr', 'spelling']),
#  'aweSOM': PackageMetadata(name='aweSOM', version='1.3', depends=[], imports=['kohonen', 'shiny', 'htmlwidgets', 'bslib', 'rmarkdown', 'htmltools', 'rclipboard', 'ggplot2', 'RColorBrewer', 'viridis', 'data.table', 'DT', 'kernlab', 'fields', 'stats', 'cluster', 'e1071', 'haven', 'foreign', 'readxl', 'readODS'], linking_to=[], suggests=['knitr']),
#  'awinR': PackageMetadata(name='awinR', version='0.1.0', depends=[], imports=['jsonlite'], linking_to=[], suggests=['knitr', 'rmarkdown', 'dplyr', 'ggplot2', 'tidyr', 'curl']),
#  'AWR': PackageMetadata(name='AWR', version='1.11.189-1', depends=[], imports=['rJava'], linking_to=[], suggests=[]),
#  'AWR.Kinesis': PackageMetadata(name='AWR.Kinesis', version='1.7.6', depends=[], imports=['AWR', 'logger', 'jsonlite', 'rJava'], linking_to=[], suggests=[]),
#  'aws': PackageMetadata(name='aws', version='2.5-6', depends=['awsMethods'], imports=['methods', 'gsl'], linking_to=[], suggests=[]),
#  'aws.alexa': PackageMetadata(name='aws.alexa', version='0.1.8', depends=[], imports=['httr', 'aws.signature', 'xml2', 'dplyr'], linking_to=[], suggests=['testthat', 'rmarkdown', 'knitr', 'lintr']),
#  'aws.comprehend': PackageMetadata(name='aws.comprehend', version='0.2.1', depends=[], imports=['httr', 'jsonlite', 'aws.signature'], linking_to=[], suggests=['testthat']),
#  'aws.ec2metadata': PackageMetadata(name='aws.ec2metadata', version='0.2.0', depends=[], imports=['curl', 'jsonlite'], linking_to=[], suggests=[]),
#  'aws.ecx': PackageMetadata(name='aws.ecx', version='1.0.5', depends=[], imports=['methods', 'rjson', 'aws.signature', 'httr', 'xml2', 'utils'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'aws.iam': PackageMetadata(name='aws.iam', version='0.1.8', depends=[], imports=['utils', 'httr', 'xml2', 'jsonlite', 'aws.signature'], linking_to=[], suggests=[]),
#  'aws.kms': PackageMetadata(name='aws.kms', version='0.1.4', depends=[], imports=['httr', 'jsonlite', 'base64enc', 'aws.signature'], linking_to=[], suggests=[]),
#  'aws.lambda': PackageMetadata(name='aws.lambda', version='0.2.0', depends=[], imports=['utils', 'httr', 'jsonlite', 'aws.signature', 'base64enc'], linking_to=[], suggests=['testthat', 'aws.s3', 'aws.iam']),
#  'aws.polly': PackageMetadata(name='aws.polly', version='0.1.5', depends=[], imports=['httr', 'jsonlite', 'aws.signature', 'tuneR'], linking_to=[], suggests=[]),
#  'aws.s3': PackageMetadata(name='aws.s3', version='0.3.22', depends=[], imports=['utils', 'tools', 'curl', 'httr', 'xml2', 'base64enc', 'digest', 'aws.signature'], linking_to=[], suggests=['testthat', 'datasets']),
#  'aws.signature': PackageMetadata(name='aws.signature', version='0.6.0', depends=[], imports=['digest', 'base64enc'], linking_to=[], suggests=['testthat', 'aws.ec2metadata']),
#  'aws.transcribe': PackageMetadata(name='aws.transcribe', version='0.1.3', depends=[], imports=['tools', 'httr', 'jsonlite', 'aws.signature'], linking_to=[], suggests=['testthat']),
#  'aws.translate': PackageMetadata(name='aws.translate', version='0.1.4', depends=[], imports=['httr', 'jsonlite', 'aws.signature'], linking_to=[], suggests=[]),
#  'aws.wrfsmn': PackageMetadata(name='aws.wrfsmn', version='0.1.0', depends=[], imports=['aws.s3', 'lubridate', 'terra', 'dplyr', 'ggplot2', 'hydroGOF', 'stats', 'magrittr'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'awsMethods': PackageMetadata(name='awsMethods', version='1.1-1', depends=['methods'], imports=[], linking_to=[], suggests=[]),
#  'axisandallies': PackageMetadata(name='axisandallies', version='0.1.1', depends=[], imports=[], linking_to=[], suggests=[]),
#  'AZIAD': PackageMetadata(name='AZIAD', version='0.0.3', depends=[], imports=['extraDistr', 'methods', 'foreach', 'doParallel', 'parallel', 'QRM', 'stats', 'corpcor', 'base', 'EnvStats'], linking_to=[], suggests=['testthat']),
#  'azlogr': PackageMetadata(name='azlogr', version='0.0.6', depends=[], imports=['caTools', 'digest', 'httr', 'jsonlite', 'logger'], linking_to=[], suggests=['covr', 'knitr', 'mockery', 'pkgdown', 'rmarkdown', 'testthat']),
#  'azr': PackageMetadata(name='azr', version='0.2.0', depends=[], imports=['methods', 'utils', 'R6', 'cli', 'httr2', 'jsonlite', 'rlang'], linking_to=[], suggests=['data.table', 'httpuv', 'clipr', 'processx', 'testthat', 'vcr']),
#  'AzureAppInsights': PackageMetadata(name='AzureAppInsights', version='0.3.1', depends=[], imports=['shiny', 'rlang', 'assertthat', 'jsonlite', 'lubridate'], linking_to=[], suggests=['testthat', 'here']),
#  'AzureAuth': PackageMetadata(name='AzureAuth', version='1.3.3', depends=[], imports=['utils', 'httr', 'openssl', 'jsonlite', 'jose', 'R6', 'rappdirs'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat', 'httpuv', 'shiny', 'shinyjs', 'AzureRMR', 'AzureGraph']),
#  'AzureCognitive': PackageMetadata(name='AzureCognitive', version='1.0.2', depends=[], imports=['AzureAuth', 'AzureRMR', 'jsonlite', 'httr'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat']),
#  'AzureContainers': PackageMetadata(name='AzureContainers', version='1.3.3', depends=[], imports=['utils', 'AzureRMR', 'AzureGraph', 'openssl', 'httr', 'R6', 'processx'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat', 'uuid', 'MASS', 'bcrypt', 'randomForest', 'plumber', 'RestRserve', 'AzureKeyVault']),
#  'AzureCosmosR': PackageMetadata(name='AzureCosmosR', version='1.0.0', depends=[], imports=['utils', 'AzureRMR', 'curl', 'openssl', 'jsonlite', 'httr', 'uuid', 'vctrs'], linking_to=[], suggests=['AzureTableStor', 'mongolite', 'DBI', 'odbc', 'dplyr', 'testthat', 'knitr', 'rmarkdown']),
#  'AzureGraph': PackageMetadata(name='AzureGraph', version='1.3.5', depends=[], imports=['AzureAuth', 'utils', 'httr', 'jsonlite', 'openssl', 'curl', 'R6'], linking_to=[], suggests=['AzureRMR', 'vctrs', 'knitr', 'rmarkdown', 'testthat']),
#  'AzureKeyVault': PackageMetadata(name='AzureKeyVault', version='1.0.6', depends=[], imports=['utils', 'R6', 'httr', 'jsonlite', 'openssl', 'jose', 'AzureRMR', 'AzureGraph', 'AzureAuth'], linking_to=[], suggests=['AzureStor', 'knitr', 'rmarkdown', 'testthat']),
#  'AzureKusto': PackageMetadata(name='AzureKusto', version='1.1.4', depends=[], imports=['rlang', 'methods', 'utils', 'httr', 'jsonlite', 'R6', 'openssl', 'AzureAuth', 'AzureRMR', 'tibble', 'dplyr', 'tidyr', 'tidyselect', 'DBI'], linking_to=[], suggests=['bit64', 'knitr', 'testthat', 'AzureGraph', 'AzureStor', 'rmarkdown']),
#  'azuremapsr': PackageMetadata(name='azuremapsr', version='0.0.2', depends=[], imports=['geojsonsf', 'httr2', 'jsonlite', 'lubridate', 'purrr', 'rlist', 'sf', 'stringr'], linking_to=[], suggests=[]),
#  'azuremlsdk': PackageMetadata(name='azuremlsdk', version='1.10.0', depends=[], imports=['ggplot2', 'reticulate', 'plyr', 'DT', 'rstudioapi', 'htmltools', 'servr', 'shiny', 'shinycssloaders'], linking_to=[], suggests=['rmarkdown', 'knitr', 'testthat', 'dplyr', 'jsonlite', 'foreach', 'iterators', 'utils']),
#  'AzureQstor': PackageMetadata(name='AzureQstor', version='1.0.2', depends=[], imports=['utils', 'AzureRMR', 'AzureStor', 'openssl', 'httr'], linking_to=[], suggests=['testthat', 'knitr', 'rmarkdown']),
#  'AzureRMR': PackageMetadata(name='AzureRMR', version='2.4.5', depends=[], imports=['AzureGraph', 'AzureAuth', 'utils', 'parallel', 'httr', 'jsonlite', 'R6', 'uuid'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat', 'httpuv', 'AzureStor']),
#  'AzureStor': PackageMetadata(name='AzureStor', version='3.7.1', depends=[], imports=['utils', 'R6', 'httr', 'mime', 'openssl', 'xml2', 'vctrs', 'AzureRMR'], linking_to=[], suggests=['AzureAuth', 'readr', 'knitr', 'rmarkdown', 'jsonlite', 'testthat', 'processx', 'uuid']),
#  'AzureTableStor': PackageMetadata(name='AzureTableStor', version='1.0.0', depends=[], imports=['utils', 'AzureRMR', 'AzureStor', 'jsonlite', 'openssl', 'httr', 'uuid', 'vctrs'], linking_to=[], suggests=['testthat', 'knitr', 'rmarkdown']),
#  'AzureVision': PackageMetadata(name='AzureVision', version='1.0.2', depends=[], imports=['AzureRMR', 'AzureCognitive', 'httr', 'utils'], linking_to=[], suggests=['knitr', 'rmarkdown', 'AzureAuth', 'testthat']),
#  'AzureVM': PackageMetadata(name='AzureVM', version='2.2.2', depends=[], imports=['R6', 'AzureRMR', 'jsonlite'], linking_to=[], suggests=['knitr', 'rmarkdown', 'testthat', 'parallel', 'AzureKeyVault', 'AzureVMmetadata']),
#  'AzureVMmetadata': PackageMetadata(name='AzureVMmetadata', version='1.0.1', depends=[], imports=['openssl', 'httr'], linking_to=[], suggests=['AzureAuth', 'AzureVM']),
#  'b64': PackageMetadata(name='b64', version='0.1.7', depends=[], imports=[], linking_to=[], suggests=['blob', 'testthat']),
#  'babel': PackageMetadata(name='babel', version='0.3-0', depends=['edgeR'], imports=['parallel'], linking_to=[], suggests=['R.rsp', 'R.devices', 'R.utils']),
#  'babelgene': PackageMetadata(name='babelgene', version='22.9', depends=[], imports=['dplyr', 'methods', 'rlang'], linking_to=[], suggests=['covr', 'knitr', 'rmarkdown', 'testthat']),
#  'babelmixr2': PackageMetadata(name='babelmixr2', version='0.1.11', depends=[], imports=['checkmate', 'cli', 'digest', 'lotri', 'nlmixr2data', 'nlmixr2extra', 'nlmixr2plot', 'magrittr', 'nlmixr2est', 'nonmem2rx', 'monolix2rx', 'methods', 'qs2', 'rex', 'rxode2'], linking_to=['Rcpp', 'rxode2', 'RcppArmadillo', 'RcppEigen'], suggests=['testthat', 'withr', 'lixoftConnectors', 'PKNCA', 'rmarkdown', 'spelling', 'PopED', 'units', 'nlme', 'dplyr', 'devtools', 'memoise', 'FME', 'coda', 'crayon']),
#  'babelwhale': PackageMetadata(name='babelwhale', version='1.2.0', depends=[], imports=['crayon', 'dplyr', 'fs', 'dynutils', 'processx', 'purrr', 'utils', 'digest', 'glue'], linking_to=[], suggests=['covr', 'testthat']),
#  'babette': PackageMetadata(name='babette', version='2.3.4', depends=['beautier', 'beastier', 'mauricer', 'tracerer'], imports=['phangorn', 'rlang', 'stringr', 'xml2'], linking_to=[], suggests=['ape', 'ggplot2', 'knitr', 'lintr', 'nLTT', 'rappdirs', 'rmarkdown', 'spelling', 'testthat']),
#  'babynames': PackageMetadata(name='babynames', version='1.0.1', depends=[], imports=['tibble'], linking_to=[], suggests=['testthat']),
#  'babynamesIL': PackageMetadata(name='babynamesIL', version='0.0.2', depends=[], imports=['tibble'], linking_to=[], suggests=['testthat', 'dplyr', 'knitr', 'rmarkdown']),
#  ...}

# %%
CRAN_INDEX["Hmisc"]
# Out:
# PackageMetadata(name='Hmisc', version='5.2-4', depends=[], imports=['methods', 'ggplot2', 'cluster', 'rpart', 'nnet', 'foreign', 'gtable', 'grid', 'gridExtra', 'data.table', 'htmlTable', 'viridisLite', 'htmltools', 'base64enc', 'colorspace', 'rmarkdown', 'knitr', 'Formula'], linking_to=[], suggests=['survival', 'qreport', 'acepack', 'chron', 'rms', 'mice', 'rstudioapi', 'tables', 'plotly', 'rlang', 'VGAM', 'leaps', 'pcaPP', 'digest', 'parallel', 'polspline', 'abind', 'kableExtra', 'rio', 'lattice', 'latticeExtra', 'gt', 'sparkline', 'jsonlite', 'htmlwidgets', 'qs', 'getPass', 'keyring', 'safer', 'htm2txt', 'boot'])

# %%
import pickle

with open("cran_index.pkl", "wb") as f:
    pickle.dump(CRAN_INDEX, f)

print("Saved cran_index.pkl")
# Out:
# Saved cran_index.pkl

# %%
# test loading and comparing
with open("cran_index.pkl", "rb") as f:
    loaded_index = pickle.load(f)
assert loaded_index == CRAN_INDEX
print("Loaded index matches the original.")
# Out:
# Loaded index matches the original.
