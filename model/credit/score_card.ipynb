# %%
import wget

url = 'https://github.com/DrIanGregory/Kaggle-GiveMeSomeCredit/raw/master/data/GiveMeSomeCredit-training.csv'
filename = 'GiveMeSomeCredit-training.csv'
wget.download(url, filename)

url = 'https://github.com/DrIanGregory/Kaggle-GiveMeSomeCredit/raw/master/data/GiveMeSomeCredit-testing.csv'
filename = 'GiveMeSomeCredit-testing.csv'
wget.download(url, filename)
# Out:
# 'GiveMeSomeCredit-testing.csv'

# %%
import pandas as pd

df = pd.read_csv('GiveMeSomeCredit-testing.csv')
print(df.iloc[0,:])
print(len(df))
# Out:
# Unnamed: 0                                 1.000000
# SeriousDlqin2yrs                                NaN
# RevolvingUtilizationOfUnsecuredLines       0.885519
# age                                       43.000000
# NumberOfTime30-59DaysPastDueNotWorse       0.000000
# DebtRatio                                  0.177513
# MonthlyIncome                           5700.000000
# NumberOfOpenCreditLinesAndLoans            4.000000
# NumberOfTimes90DaysLate                    0.000000
# NumberRealEstateLoansOrLines               0.000000
# NumberOfTime60-89DaysPastDueNotWorse       0.000000
# NumberOfDependents                         0.000000
# Name: 0, dtype: float64
# 101503

# %%
df_train = pd.read_csv('GiveMeSomeCredit-training.csv')
df_test = pd.read_csv('GiveMeSomeCredit-testing.csv')

# %%
df_train.columns
# Out:
# Index(['Unnamed: 0', 'SeriousDlqin2yrs',
#        'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents'],
#       dtype='object')

# %%
df_train["SeriousDlqin2yrs"].value_counts(dropna=False)
# Out:
# SeriousDlqin2yrs
# 0    139974
# 1     10026
# Name: count, dtype: int64

# %%
df_train["SeriousDlqin2yrs"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SeriousDlqin2yrs'>

# %%
df_train["RevolvingUtilizationOfUnsecuredLines"].hist(bins=20, range=(0,1))
# Out:
# <Axes: >

# %%
import category_encoders as ce
import matplotlib.pyplot as plt

# Create an encoder object
encoder = ce.WOEEncoder(cols=['RevolvingUtilizationOfUnsecuredLines'])

# Encode the target variable
encoder.fit(df_train['RevolvingUtilizationOfUnsecuredLines'], df_train['SeriousDlqin2yrs'])
res = encoder.transform(df_train['RevolvingUtilizationOfUnsecuredLines'])
# Out:
# c:\Users\yzdom\AppData\Local\Programs\Python\Python312\Lib\site-packages\category_encoders\ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# c:\Users\yzdom\AppData\Local\Programs\Python\Python312\Lib\site-packages\category_encoders\ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# ...

# %%
df_train["age"].hist(bins=20, range=(0,100))
# Out:
# <Axes: >

# %%
df_train["NumberOfTime30-59DaysPastDueNotWorse"].hist(bins=20, range=(0,5))
# Out:
# <Axes: >

# %%
df_train["NumberOfTime60-89DaysPastDueNotWorse"].hist(bins=20, range=(0,5))
# Out:
# <Axes: >

# %%
df_train["DebtRatio"].hist(bins=20, range=(0,2))
# Out:
# <Axes: >

# %%
df_train["MonthlyIncome"].hist(bins=20, range=(0,20000))
# Out:
# <Axes: >

# %%
df_train["NumberOfOpenCreditLinesAndLoans"].hist(bins=20, range=(0,30))
# Out:
# <Axes: >

# %%
df_train["NumberOfTimes90DaysLate"].hist(bins=20, range=(0,3))
# Out:
# <Axes: >

# %%
df_train["NumberRealEstateLoansOrLines"].hist(bins=20, range=(0,5))
# Out:
# <Axes: >

# %%
df_train["NumberOfDependents"].hist(bins=20, range=(0,5))
# Out:
# <Axes: >
