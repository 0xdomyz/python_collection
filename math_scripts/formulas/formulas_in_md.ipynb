# %% [markdown]
# Division:
# `$$\frac{a}{b}$$`
# $$\frac{a}{b}$$
#
# Addition:
# `$$a + b$$`
# `$$a - b$$`
# $$a + b$$
# $$a - b$$
#
# Multiplication:
# `$$a \times b$$`
# `$$a \cdot b$$`
# $$a \times b$$
# $$a \cdot b$$
#
# Summation:
# `$$\sum_{i=1}^{n} a_i$$`
# $$\sum_{i=1}^{n} a_i$$
#
# Product:
# `$$\prod_{i=1}^{n} a_i$$`
# $$\prod_{i=1}^{n} a_i$$
#
# Limit:
# `$$\lim_{x \to a} f(x)$$`
# $$\lim_{x \to a} f(x)$$

# %% [markdown]
# subscript and power
#
# `$$a_{i=1}^3$$`
# $$a_{i=1}^3$$

# %% [markdown]
# Quadratic formula:
#
# `$$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$`
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
#
# Pythagorean theorem:
#
# `$$a^2 + b^2 = c^2$$`
# $$a^2 + b^2 = c^2$$
#
# Euler's formula:
#
# `$$e^{ix} = \cos(x) + i\sin(x)$$`
# $$e^{ix} = \cos(x) + i\sin(x)$$
#
# Binomial theorem:
#
# `$$ (x+y)^n = \sum_{k=0}^{n} {n \choose k} x^{n-k} y^k $$`
# $$ (x+y)^n = \sum_{k=0}^{n} {n \choose k} x^{n-k} y^k $$
#
# Trigonometric identities:
#
# `$$\sin^2(x) + \cos^2(x) = 1$$`
# $$\sin^2(x) + \cos^2(x) = 1$$
#
# `$$\tan(x) = \frac{\sin(x)}{\cos(x)}$$`
# $$\tan(x) = \frac{\sin(x)}{\cos(x)}$$
#
# Derivative of a function:
#
# `$$\frac{d}{dx}f(x) = f'(x)$$`
# $$\frac{d}{dx}f(x) = f'(x)$$
#
# Integral of a function:
#
# `$$\int f(x) dx$$`
# $$\int f(x) dx$$

# %% [markdown]
# Given the function $f(x) = x^2$, we can find its derivative using the power rule:
#
# `$$`
#
# `\begin{align*}`
#
# `f'(x) &= \frac{d}{dx}x^2 \\`
#
# `      &= 2x`
#
# `\end{align*}`
#
# `$$`
#
# $$
# \begin{align*}
# f'(x) &= \frac{d}{dx}x^2 \\
#       &= 2x
# \end{align*}
# $$

# %% [markdown]
# price of a call option (C) and a put option (P) according to the Black-Scholes
#
# `$$C = S_0 e^{-qt} N(d_1) - X e^{-rt} N(d_2)$$`
# $$C = S_0 e^{-qt} N(d_1) - X e^{-rt} N(d_2)$$
#
# `$$P = X e^{-rt} N(-d_2) - S_0 e^{-qt} N(-d_1)$$`
# $$P = X e^{-rt} N(-d_2) - S_0 e^{-qt} N(-d_1)$$
#
# `$$d_1 = \frac{1}{\sigma \sqrt{t}} \left[ \ln\left(\frac{S_0}{X}\right) + \left(r - q + \frac{\sigma^2}{2}\right) t \right]$$`
# $$d_1 = \frac{1}{\sigma \sqrt{t}} \left[ \ln\left(\frac{S_0}{X}\right) + \left(r - q + \frac{\sigma^2}{2}\right) t \right]$$
#
# `$$d_2 = d_1 - \sigma \sqrt{t}$$`
# $$d_2 = d_1 - \sigma \sqrt{t}$$
#
# `$$d1 = \frac{\ln\left(\frac{S}{K}\right) + \left(r + \frac{1}{2}\sigma^2\right)T}{\sigma\sqrt{T}}$$`
# $$d1 = \frac{\ln\left(\frac{S}{K}\right) + \left(r + \frac{1}{2}\sigma^2\right)T}{\sigma\sqrt{T}}$$
#
# `$$d2 = d1 - \sigma\sqrt{T}$$`
# $$d2 = d1 - \sigma\sqrt{T}$$

# %% [markdown]
# std brown
#
# `- $W(0) = 0$`
#
# `- For $0 \leq s < t$, the increment $W(t) - W(s)$ is normally distributed with mean 0 and variance $t - s$, i.e., $W(t) - W(s) \sim N(0, t - s)$.`
#
# `- The increments are independent: for $0 \leq s < t \leq u < v$, the increments $W(t) - W(s)$ and $W(v) - W(u)$ are independent.`
#
# - $W(0) = 0$
# - For $0 \leq s < t$, the increment $W(t) - W(s)$ is normally distributed with mean 0 and variance $t - s$, i.e., $W(t) - W(s) \sim N(0, t - s)$.
# - The increments are independent: for $0 \leq s < t \leq u < v$, the increments $W(t) - W(s)$ and $W(v) - W(u)$ are independent.
#
# geo brown
#
# `$$dS(t) = \mu S(t) dt + \sigma S(t) dW(t)$$`
# $$dS(t) = \mu S(t) dt + \sigma S(t) dW(t)$$
#
# `$$S(t) = S(0) \exp\left((\mu - \frac{1}{2}\sigma^2)t + \sigma W(t)\right)$$`
# $$S(t) = S(0) \exp\left((\mu - \frac{1}{2}\sigma^2)t + \sigma W(t)\right)$$

# %% [markdown]
# logistic func
#
# `$$f(x) = \frac{1}{1 + e^{-x}}$$`
#
# $$f(x) = \frac{1}{1 + e^{-x}}$$
#
# logisic reg model
#
# `$$P(y=1|x) = \frac{1}{1 + e^{-(b_0 + b_1 \cdot x)}}$$`
#
# $$P(y=1|x) = \frac{1}{1 + e^{-(b_0 + b_1 \cdot x)}}$$
#
# maximise LL for logistic reg model data
#
# `$$LL = \sum_{i=1}^{n} [y_i \cdot \log(f(x_i)) + (1 - y_i) \cdot \log(1 - f(x_i))]$$`
#
# $$LL = \sum_{i=1}^{n} [y_i \cdot \log(f(x_i)) + (1 - y_i) \cdot \log(1 - f(x_i))]$$
#
# points to double the odds
#
# `$$Score = Offset - PDO \cdot \log(Odds)$$`
#
# $$Score = Offset - PDO \cdot \log(Odds)$$
#
# error
#
# `$$MSE = \frac{1}{n} \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2$$`
#
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2$$
#
# `$$Gini = 2 \cdot AUC - 1$$`
#
# $$Gini = 2 \cdot AUC - 1$$
#
# GLM
#
# `$$\eta = \beta_0 + \beta_1X_1 + \beta_2X_2 + ... + \beta_pX_p$$`
#
# `$$g(E(Y)) = \eta$$`
#
# `$$g(E(Y)) = \ln\left(\frac{E(Y)}{1 - E(Y)}\right) = \eta$$`
#
# $$\eta = \beta_0 + \beta_1X_1 + \beta_2X_2 + ... + \beta_pX_p$$
#
# $$g(E(Y)) = \eta$$
#
# $$g(E(Y)) = \ln\left(\frac{E(Y)}{1 - E(Y)}\right) = \eta$$

# %% [markdown]
# stats
#
# `$$E[X] = \sum_{i=1}^{n} x_i \cdot P(x_i)$$`
#
# `$$Var[X] = E[(X - E[X])^2] = E[X^2] - (E[X])^2$$`
#
# `$$Skewness[X] = E\left[\left(\frac{X - E[X]}{\sqrt{Var[X]}}\right)^3\right]$$`
#
# $$E[X] = \sum_{i=1}^{n} x_i \cdot P(x_i)$$
#
# $$Var[X] = E[(X - E[X])^2] = E[X^2] - (E[X])^2$$
#
# $$Skewness[X] = E\left[\left(\frac{X - E[X]}{\sqrt{Var[X]}}\right)^3\right]$$
#
# normal pdf
#
# `$$f(x) = \frac{1}{\sqrt{2\pi\sigma^2}} e^{ -\frac{(x-\mu)^2}{2\sigma^2} }$$`
#
# $$f(x) = \frac{1}{\sqrt{2\pi\sigma^2}} e^{ -\frac{(x-\mu)^2}{2\sigma^2} }$$
#
# bayes
#
# `$$P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}$$`
#
# `$$P(\theta|D) = \frac{P(D|\theta) \cdot P(\theta)}{P(D)}$$`
#
# `$$P(\theta|D) \propto P(D|\theta) \cdot P(\theta)$$`
#
# $$P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}$$
#
# $$P(\theta|D) = \frac{P(D|\theta) \cdot P(\theta)}{P(D)}$$
#
# $$P(\theta|D) \propto P(D|\theta) \cdot P(\theta)$$

# %% [markdown]
# integration by parts
#
# `$$\int u dv = u \cdot v - \int v du$$`
#
# `- $u = x$ (so $du = dx$), and`
#
# `- $dv = e^x dx$ (so $v = e^x$).`
#
# $$\int u dv = u \cdot v - \int v du$$
#
# Let's choose:
# - $u = x$ (so $du = dx$), and
# - $dv = e^x dx$ (so $v = e^x$).
#
# Then, according to the formula, we have:
#
# `$$\int x e^x dx = x \cdot e^x - \int e^x dx$$`
#
# $$\int x e^x dx = x \cdot e^x - \int e^x dx$$
#
# `The integral $\int e^x dx$ is simply $e^x$, so we get:`
#
# The integral $\int e^x dx$ is simply $e^x$, so we get:
#
# `$$\int x e^x dx = x \cdot e^x - e^x + C$$`
#
# $$\int x e^x dx = x \cdot e^x - e^x + C$$
#
# where $C$ is the constant of integration.

# %% [markdown]
# Operators
#
# | Symbol | Rendered |
# |--------|----------|
# | `*`    | *        |
# | `_`    | _        |
# | `**`   | **       |
# | `__`   | __       |
# | `~`    | ~        |
# | `^`    | ^        |
# | `==`   | ==       |
# | `!=`   | !=       |
# | `<`    | <        |
# | `>`    | >        |
# | `<=`   | <=       |
# | `>=`   | >=       |
# | `+-`   | ±        |
# | `/`    | /        |
# | `//`   | //       |
# | `%`    | %        |
# | `|`    | \|       |
# | `[]`   | []       |
# | `()`   | ()       |
# | `{}`   | {}       |
# | `[]()` | []()     |

# %% [markdown]
# greeks
#
# | Symbol | Rendered |
# |--------|----------|
# | `\alpha` | α |
# | `\beta` | β |
# | `\gamma` | γ |
# | `\delta` | δ |
# | `\epsilon` | ε |
# | `\zeta` | ζ |
# | `\eta` | η |
# | `\theta` | θ |
# | `\iota` | ι |
# | `\kappa` | κ |
# | `\lambda` | λ |
# | `\mu` | μ |
# | `\nu` | ν |
# | `\xi` | ξ |
# | `\pi` | π |
# | `\rho` | ρ |
# | `\sigma` | σ |
# | `\tau` | τ |
# | `\upsilon` | υ |
# | `\phi` | φ |
# | `\chi` | χ |
# | `\psi` | ψ |
# | `\omega` | ω |
