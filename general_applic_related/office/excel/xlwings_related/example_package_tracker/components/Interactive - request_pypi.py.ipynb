# %% [markdown]
# Connected to Python 3.13.2

# %%
import requests

response = requests.get("https://pypi.org/pypi/xlwings/json")
response.status_code
# Out:
# 200

# %%
js = response.json()

# %%
js.keys()
# Out:
# dict_keys(['info', 'last_serial', 'ownership', 'releases', 'urls', 'vulnerabilities'])

# %%
js['releases']
# Out:
# {'0.1.0': [{'comment_text': '',
#    'digests': {'blake2b_256': '64a70ce0d0b27d82f27ffcc7f4219bcbc492047e2840517d98524671cd3a4620',
#     'md5': '4aa10c081fb02ea3ca6fadd3e2858133',
#     'sha256': '9776037773761de11565997a82def45430682f9614b59ec44bc75eb5ca6247b0'},
#    'downloads': -1,
#    'filename': 'xlwings-0.1.0.zip',
#    'has_sig': False,
#    'md5_digest': '4aa10c081fb02ea3ca6fadd3e2858133',
#    'packagetype': 'sdist',
#    'python_version': 'source',
#    'requires_python': None,
#    'size': 23456,
#    'upload_time': '2014-03-19T18:18:49',
#    'upload_time_iso_8601': '2014-03-19T18:18:49.666294Z',
#    'url': 'https://files.pythonhosted.org/packages/64/a7/0ce0d0b27d82f27ffcc7f4219bcbc492047e2840517d98524671cd3a4620/xlwings-0.1.0.zip',
#    'yanked': False,
#    'yanked_reason': None}],
#  '0.1.1': [{'comment_text': '',
#    'digests': {'blake2b_256': '6c33556f6b500b944921dd49ed756d709d4782c43218a1054957a490a377b3cf',
#     'md5': 'f0244b373e2d251b20689620d6437c00',
# ...

# %%
type(js['releases'])
# Out:
# dict
