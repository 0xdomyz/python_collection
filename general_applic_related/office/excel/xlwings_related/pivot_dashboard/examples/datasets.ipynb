# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
def inspect(df):
    df_info = pd.concat([
        df.head(1).T, df.dtypes.astype(str), df.nunique(), df.isna().sum(),
        df.describe(include="all").T[["min", "max"]]], axis=1) # fmt: skip
    df_info.columns = ["example_value", "dtypes", "nunique", "n_null", "min", "max"]
    df_info = df_info.sort_index().sort_values("dtypes")
    print(df_info.to_string())
    print(df.shape)
    print(df.head().to_string())

# %% [markdown]
# ### section

# %%
df = sns.load_dataset("attention")
inspect(df)
# Out:
#            example_value   dtypes  nunique  n_null  min   max
# score                2.0  float64        9       0  2.0   9.0
# Unnamed: 0             0    int64       60       0  0.0  59.0
# solutions              1    int64        3       0  1.0   3.0
# subject                1    int64       20       0  1.0  20.0
# attention        divided   object        2       0  NaN   NaN
# (60, 5)
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0
# 2           2        3   divided          1    3.0
# 3           3        4   divided          1    5.0
# 4           4        5   divided          1    4.0

# %%
df = sns.load_dataset("car_crashes")
inspect(df)
# Out:
#                example_value   dtypes  nunique  n_null     min      max
# alcohol                 5.64  float64       50       0   1.593   10.038
# ins_losses            145.08  float64       51       0   82.75   194.78
# ins_premium           784.55  float64       51       0  641.96  1301.52
# no_previous            15.04  float64       50       0     5.9    21.28
# not_distracted        18.048  float64       50       0    1.76   23.661
# speeding               7.332  float64       50       0   1.792     9.45
# total                   18.8  float64       45       0     5.9     23.9
# abbrev                    AL   object       51       0     NaN      NaN
# (51, 8)
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  ins_losses abbrev
# 0   18.8     7.332    5.640          18.048       15.040       784.55      145.08     AL
# 1   18.1     7.421    4.525          16.290       17.014      1053.48      133.93     AK
# 2   18.6     6.510    5.208          15.624       17.856       899.47      110.35     AZ
# 3   22.4     4.032    5.824          21.056       21.280       827.34      142.39     AR
# 4   12.0     4.200    3.360          10.920       10.680       878.41      165.63     CA

# %%
df = sns.load_dataset("diamonds")
inspect(df)
# Out:
#         example_value    dtypes  nunique  n_null    min      max
# clarity           SI2  category        8       0    NaN      NaN
# color               E  category        7       0    NaN      NaN
# cut             Ideal  category        5       0    NaN      NaN
# carat            0.23   float64      273       0    0.2     5.01
# depth            61.5   float64      184       0   43.0     79.0
# table            55.0   float64      127       0   43.0     95.0
# x                3.95   float64      554       0    0.0    10.74
# y                3.98   float64      552       0    0.0     58.9
# z                2.43   float64      375       0    0.0     31.8
# price             326     int64    11602       0  326.0  18823.0
# (53940, 10)
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df = sns.load_dataset("dots")
inspect(df)
# Out:
#             example_value   dtypes  nunique  n_null      min      max
# coherence             0.0  float64        6       0      0.0     51.2
# firing_rate     33.189967  float64      834       0  6.27572  70.0489
# time                  -80    int64       67       0   -600.0    720.0
# align                dots   object        2       0      NaN      NaN
# choice                 T1   object        2       0      NaN      NaN
# (848, 5)
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
df = sns.load_dataset("dowjones")
inspect(df)
# Out:
#              example_value          dtypes  nunique  n_null                  min                  max
# Date   1914-12-01 00:00:00  datetime64[ns]      649       0  1914-12-01 00:00:00  1968-12-01 00:00:00
# Price                 55.0         float64      637       0                46.85               985.93
# (649, 2)
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
df = sns.load_dataset("exercise")
inspect(df)
# Out:
#            example_value    dtypes  nunique  n_null   min    max
# diet             low fat  category        2       0   NaN    NaN
# kind                rest  category        3       0   NaN    NaN
# time               1 min  category        3       0   NaN    NaN
# Unnamed: 0             0     int64       90       0   0.0   89.0
# id                     1     int64       30       0   1.0   30.0
# pulse                 85     int64       39       0  80.0  150.0
# (90, 6)
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
df = sns.load_dataset("fmri")
inspect(df)
# Out:
#           example_value   dtypes  nunique  n_null       min       max
# signal        -0.017552  float64     1064       0 -0.255486  0.564985
# timepoint            18    int64       19       0       0.0      18.0
# event              stim   object        2       0       NaN       NaN
# region         parietal   object        2       0       NaN       NaN
# subject             s13   object       14       0       NaN       NaN
# (1064, 5)
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df = sns.load_dataset("geyser")
inspect(df)
# Out:
#          example_value   dtypes  nunique  n_null   min   max
# duration           3.6  float64      126       0   1.6   5.1
# waiting             79    int64       51       0  43.0  96.0
# kind              long   object        2       0   NaN   NaN
# (272, 3)
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %%
df = sns.load_dataset("glue")
inspect(df)
# Out:
#         example_value   dtypes  nunique  n_null     min     max
# Score            75.5  float64       56       0    11.6    97.8
# Year             2019    int64        3       0  2017.0  2019.0
# Encoder   Transformer   object        2       0     NaN     NaN
# Model           ERNIE   object        8       0     NaN     NaN
# Task             CoLA   object        8       0     NaN     NaN
# (64, 5)
#          Model  Year      Encoder  Task  Score
# 0        ERNIE  2019  Transformer  CoLA   75.5
# 1           T5  2019  Transformer  CoLA   71.6
# 2      RoBERTa  2019  Transformer  CoLA   67.8
# 3         BERT  2018  Transformer  CoLA   60.5
# 4  BiLSTM+ELMo  2018         LSTM  CoLA   32.1

# %%
df = sns.load_dataset("healthexp")
inspect(df)
# Out:
#                 example_value   dtypes  nunique  n_null      min        max
# Life_Expectancy          70.6  float64      118       0     70.6       84.7
# Spending_USD          252.311  float64      274       0  123.993  11859.179
# Year                     1970    int64       51       0   1970.0     2020.0
# Country               Germany   object        6       0      NaN        NaN
# (274, 4)
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
df = sns.load_dataset("iris")
inspect(df)
# Out:
#              example_value   dtypes  nunique  n_null  min  max
# petal_length           1.4  float64       43       0  1.0  6.9
# petal_width            0.2  float64       22       0  0.1  2.5
# sepal_length           5.1  float64       35       0  4.3  7.9
# sepal_width            3.5  float64       23       0  2.0  4.4
# species             setosa   object        3       0  NaN  NaN
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df = sns.load_dataset("mpg")
inspect(df)
# Out:
#                           example_value   dtypes  nunique  n_null     min     max
# acceleration                       12.0  float64       95       0     8.0    24.8
# displacement                      307.0  float64       82       0    68.0   455.0
# horsepower                        130.0  float64       93       6    46.0   230.0
# mpg                                18.0  float64      129       0     9.0    46.6
# cylinders                             8    int64        5       0     3.0     8.0
# model_year                           70    int64       13       0    70.0    82.0
# weight                             3504    int64      351       0  1613.0  5140.0
# name          chevrolet chevelle malibu   object      305       0     NaN     NaN
# origin                              usa   object        3       0     NaN     NaN
# (398, 9)
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year origin                       name
# 0  18.0          8         307.0       130.0    3504          12.0          70    usa  chevrolet chevelle malibu
# 1  15.0          8         350.0       165.0    3693          11.5          70    usa          buick skylark 320
# 2  18.0          8         318.0       150.0    3436          11.0          70    usa         plymouth satellite
# 3  16.0          8         304.0       150.0    3433          12.0          70    usa              amc rebel sst
# 4  17.0          8         302.0       140.0    3449          10.5          70    usa                ford torino
#
# (398, 9)
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year origin                       name
# 0  18.0          8         307.0       130.0    3504          12.0          70    usa  chevrolet chevelle malibu
# 1  15.0          8         350.0       165.0    3693          11.5          70    usa          buick skylark 320
# 2  18.0          8         318.0       150.0    3436          11.0          70    usa         plymouth satellite
# 3  16.0          8         304.0       150.0    3433          12.0          70    usa              amc rebel sst
# 4  17.0          8         302.0       140.0    3449          10.5          70    usa                ford torino

# %%
df = sns.load_dataset("penguins")
inspect(df)
# Out:
#                   example_value   dtypes  nunique  n_null     min     max
# bill_depth_mm              18.7  float64       80       2    13.1    21.5
# bill_length_mm             39.1  float64      164       2    32.1    59.6
# body_mass_g              3750.0  float64       94       2  2700.0  6300.0
# flipper_length_mm         181.0  float64       55       2   172.0   231.0
# island                Torgersen   object        3       0     NaN     NaN
# sex                        Male   object        2      11     NaN     NaN
# species                  Adelie   object        3       0     NaN     NaN
# (344, 7)
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5           17.4              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3           18.0              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN            NaN                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0       3450.0  Female

# %%
df = sns.load_dataset("planets")
inspect(df)
# Out:
#                   example_value   dtypes  nunique  n_null       min       max
# distance                   77.4  float64      552     227      1.35    8500.0
# mass                        7.1  float64      381     522    0.0036      25.0
# orbital_period            269.3  float64      988      43  0.090706  730000.0
# number                        1    int64        7       0       1.0       7.0
# year                       2006    int64       23       0    1989.0    2014.0
# method          Radial Velocity   object       10       0       NaN       NaN
# (1035, 6)
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df = sns.load_dataset("seaice")
inspect(df)
# Out:
#               example_value          dtypes  nunique  n_null                  min                  max
# Date    1980-01-01 00:00:00  datetime64[ns]    13175       0  1980-01-01 00:00:00  2019-12-31 00:00:00
# Extent                 14.2         float64     7649       0                 3.34               16.412
# (13175, 2)
#         Date  Extent
# 0 1980-01-01  14.200
# 1 1980-01-03  14.302
# 2 1980-01-05  14.414
# 3 1980-01-07  14.518
# 4 1980-01-09  14.594

# %%
df = sns.load_dataset("taxis")
inspect(df)
# Out:
#                        example_value          dtypes  nunique  n_null                  min                  max
# dropoff          2019-03-23 20:27:24  datetime64[ns]     6425       0  2019-02-28 23:32:35  2019-04-01 00:13:58
# pickup           2019-03-23 20:21:09  datetime64[ns]     6414       0  2019-02-28 23:29:03  2019-03-31 23:43:45
# distance                         1.6         float64     1079       0                  0.0                 36.7
# fare                             7.0         float64      220       0                  1.0                150.0
# tip                             2.15         float64      489       0                  0.0                 33.2
# tolls                            0.0         float64       16       0                  0.0                24.02
# total                          12.95         float64      898       0                  1.3               174.82
# passengers                         1           int64        7       0                  0.0                  6.0
# color                         yellow          object        2       0                  NaN                  NaN
# dropoff_borough            Manhattan          object        5      45                  NaN                  NaN
# dropoff_zone     UN/Turtle Bay South          object      203      45                  NaN                  NaN
# payment                  credit card          object        2      44                  NaN                  NaN
# pickup_borough             Manhattan          object        4      26                  NaN                  NaN
# pickup_zone          Lenox Hill West          object      194      26                  NaN                  NaN
# (6433, 14)
#                pickup             dropoff  passengers  distance  fare   tip  tolls  total   color      payment            pickup_zone           dropoff_zone pickup_borough dropoff_borough
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0  12.95  yellow  credit card        Lenox Hill West    UN/Turtle Bay South      Manhattan       Manhattan
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0   9.30  yellow         cash  Upper West Side South  Upper West Side South      Manhattan       Manhattan
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36    0.0  14.16  yellow  credit card          Alphabet City           West Village      Manhattan       Manhattan
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15    0.0  36.95  yellow  credit card              Hudson Sq         Yorkville West      Manhattan       Manhattan
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0  13.40  yellow  credit card           Midtown East         Yorkville West      Manhattan       Manhattan

# %%
df = sns.load_dataset("tips")
inspect(df)
# Out:
#            example_value    dtypes  nunique  n_null   min    max
# day                  Sun  category        4       0   NaN    NaN
# sex               Female  category        2       0   NaN    NaN
# smoker                No  category        2       0   NaN    NaN
# time              Dinner  category        2       0   NaN    NaN
# tip                 1.01   float64      123       0   1.0   10.0
# total_bill         16.99   float64      229       0  3.07  50.81
# size                   2     int64        6       0   1.0    6.0
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = sns.load_dataset("titanic")
inspect(df)
# Out:
#             example_value    dtypes  nunique  n_null   min       max
# adult_male           True      bool        2       0   NaN       NaN
# alone               False      bool        2       0   NaN       NaN
# class               Third  category        3       0   NaN       NaN
# deck                  NaN  category        7     688   NaN       NaN
# age                  22.0   float64       88     177  0.42      80.0
# fare                 7.25   float64      248       0   0.0  512.3292
# parch                   0     int64        7       0   0.0       6.0
# pclass                  3     int64        3       0   1.0       3.0
# sibsp                   1     int64        7       0   0.0       8.0
# survived                0     int64        2       0   0.0       1.0
# alive                  no    object        2       0   NaN       NaN
# embark_town   Southampton    object        3       2   NaN       NaN
# embarked                S    object        3       2   NaN       NaN
# sex                  male    object        2       0   NaN       NaN
# who                   man    object        3       0   NaN       NaN
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0         0       3    male  22.0      1      0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1         1       1  female  38.0      1      0  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2         1       3  female  26.0      0      0   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# 3         1       1  female  35.0      1      0  53.1000        S  First  woman       False    C  Southampton   yes  False
# 4         0       3    male  35.0      0      0   8.0500        S  Third    man        True  NaN  Southampton    no   True
