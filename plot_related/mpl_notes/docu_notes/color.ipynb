# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])
plt.imshow(I)
plt.colorbar()

# %%
plt.imshow(I, cmap="gray")

# %%
cmaps = ["binary", "viridis", "RdBu", "PuOr", "jet"]

for i, cmap in enumerate(cmaps):
    plt.subplot(2, 3, i + 1)
    plt.imshow(I, cmap=cmap)
    plt.text(500, 500, cmap, fontsize=18, ha="center")

# %%
# limits and extensions

# make noise in 1% of the image pixels
speckles = np.random.random(I.shape) < 0.01
I[speckles] = np.random.normal(0, 3, np.count_nonzero(speckles))
plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.imshow(I, cmap="RdBu")
plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(I, cmap="RdBu")
plt.colorbar(extend="both")
plt.clim(-1, 1);

# %%
# discrete bars
plt.imshow(I, cmap=plt.cm.get_cmap("Blues", 6))
plt.colorbar()
plt.clim(-1, 1);
# Out:
# C:\Users\yzdom\AppData\Local\Temp\ipykernel_16160\288874284.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 6))

# %% [markdown]
# ## handwritten chars

# %%
# load images of the digits 0 through 5 and visualize several of them
from sklearn.datasets import load_digits

digits = load_digits(n_class=6)

# %%
fig, ax = plt.subplots(8, 8, figsize=(6, 6))
for i, axi in enumerate(ax.flat):
    axi.imshow(digits.images[i], cmap="binary")
    axi.set(xticks=[], yticks=[])

# %%
# project the digits into 2 dimensions using IsoMap
from sklearn.manifold import Isomap

iso = Isomap(n_components=2)
projection = iso.fit_transform(digits.data)
# Out:
# c:\Users\yzdom\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\manifold\_isomap.py:383: UserWarning: The number of connected components of the neighbors graph is 2 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# c:\Users\yzdom\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\_index.py:102: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
# plot the results
plt.scatter(
    projection[:, 0],
    projection[:, 1],
    lw=0.1,
    c=digits.target,
    cmap=plt.cm.get_cmap("cubehelix", 6),
)
plt.colorbar(ticks=range(6), label="digit value")
plt.clim(-0.5, 5.5)
# Out:
# C:\Users\yzdom\AppData\Local\Temp\ipykernel_16160\390961122.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c=digits.target, cmap=plt.cm.get_cmap('cubehelix', 6))
