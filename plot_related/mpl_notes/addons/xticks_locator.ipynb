# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ### example

# %%
ts = pd.read_csv("flights.csv")

# prep
ts.index = pd.to_datetime(
    ts["year"].astype(str) + "-" + ts["month"].astype(str) + "-01"
)
ts["n"] = ts["passengers"]
ts.drop(columns=["year", "month", "passengers"], inplace=True)


import ta

ts["n_lag1"] = ts["n"].shift(1)
ts["n_lag3"] = ts["n"].shift(3)
ts["n_lag12"] = ts["n"].shift(12)
ts["ma12"] = ta.trend.sma_indicator(ts["n"], window=12, fillna=True)

print(ts.head().to_string())
ts.shape
# Out:
#               n  n_lag1  n_lag3  n_lag12        ma12
# 1949-01-01  112     NaN     NaN      NaN  112.000000
# 1949-02-01  118   112.0     NaN      NaN  115.000000
# 1949-03-01  132   118.0     NaN      NaN  120.666667
# 1949-04-01  129   132.0   112.0      NaN  122.750000
# 1949-05-01  121   129.0   118.0      NaN  122.400000
# (144, 5)

# %% [markdown]
# ### locator, formatter

# %%
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=5))
ax.yaxis.set_major_formatter(mpl.ticker.PercentFormatter(1.0, decimals=0))

# %%
# axis formatting
ax.set_xlabel("Date")
ax.xaxis.set_major_locator(mpl.dates.YearLocator())
ax.xaxis.set_major_formatter(mpl.dates.DateFormatter("%Y-%m-%d"))
ax.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))
ax.tick_params("x", rotation=45)

ax.set_ylabel("Counts")
ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(100))
ax.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(2))

fig

# %%
# list of locators
from matplotlib.ticker import (
    AutoLocator,
    MaxNLocator,
    LinearLocator,
    LogLocator,
    MultipleLocator,
    FixedLocator,
    IndexLocator,
    NullLocator,
    SymmetricalLogLocator,
    AsinhLocator,
    LogitLocator,
    AutoMinorLocator,
)

# %%
from matplotlib.dates import (
    YearLocator,
    MonthLocator,
    WeekdayLocator,
    DayLocator,
    HourLocator,
    MinuteLocator,
    SecondLocator,
    DateFormatter,
)

# %% [markdown]
# ### dates

# %%
import matplotlib.dates as mdates

mdates.AutoDateLocator(maxticks=3)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.plot(ts.index, ts["n"], label="n")
ax.xaxis.set_major_locator(mdates.YearLocator())

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.plot(ts.index, ts["n"], label="n")
ax.xaxis.set_major_locator(mdates.DayLocator(interval=365//2))
ax.tick_params("x", rotation=45)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.plot(ts.index, ts["n"], label="n")
ax.xaxis.set_major_locator(mdates.AutoDateLocator(minticks=30))
ax.tick_params("x", rotation=45)
