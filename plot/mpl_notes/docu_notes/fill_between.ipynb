# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### area band

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))
# plot a range with color filled in between
ax.fill_between(x, np.sin(x), np.cos(x), color="red", alpha=0.1)
