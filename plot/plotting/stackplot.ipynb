# %%
# example data of entities with percentages over columns that add up to 100%
# time from jan 2020 to dec 2021
# 5 columns with percentages

import pandas as pd
import numpy as np

df = pd.DataFrame(columns=["month", "col1", "col2", "col3", "col4", "col5"])
df["month"] = pd.date_range(start="1/1/2020", end="12/1/2021", freq="MS")
df["col1"] = np.random.randint(0, 20, size=(24)) / 100
df["col2"] = np.random.randint(0, 20, size=(24)) / 100
df["col3"] = np.random.randint(0, 20, size=(24)) / 100
df["col4"] = np.random.randint(0, 20, size=(24)) / 100
df["col5"] = 1 - df["col1"] - df["col2"] - df["col3"] - df["col4"]

df
# Out:
#         month  col1  col2  col3  col4  col5
# 0  2020-01-01  0.01  0.15  0.18  0.14  0.52
# 1  2020-02-01  0.04  0.16  0.09  0.09  0.62
# 2  2020-03-01  0.03  0.15  0.11  0.15  0.56
# 3  2020-04-01  0.06  0.07  0.11  0.13  0.63
# 4  2020-05-01  0.18  0.08  0.18  0.10  0.46
# 5  2020-06-01  0.19  0.14  0.10  0.01  0.56
# 6  2020-07-01  0.15  0.13  0.10  0.08  0.54
# 7  2020-08-01  0.11  0.03  0.13  0.16  0.57
# 8  2020-09-01  0.01  0.17  0.11  0.11  0.60
# 9  2020-10-01  0.08  0.09  0.06  0.19  0.58
# 10 2020-11-01  0.18  0.01  0.10  0.12  0.59
# 11 2020-12-01  0.13  0.10  0.14  0.06  0.57
# 12 2021-01-01  0.07  0.10  0.16  0.18  0.49
# 13 2021-02-01  0.14  0.08  0.06  0.08  0.64
# 14 2021-03-01  0.04  0.13  0.00  0.18  0.65
# 15 2021-04-01  0.06  0.01  0.15  0.03  0.75
# 16 2021-05-01  0.02  0.17  0.16  0.18  0.47
# 17 2021-06-01  0.12  0.01  0.16  0.07  0.64
# 18 2021-07-01  0.09  0.18  0.12  0.06  0.55
# 19 2021-08-01  0.16  0.19  0.12  0.17  0.36
# ...

# %%
# plot stacked line chart of percentages over time
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

args = df.columns[1:].tolist()
labels = args
plt.stackplot(df["month"], *[df[arg] for arg in args], labels=labels)
plt.legend(loc="upper left")
# x-axis only show major ticks every 3 months
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.gcf().autofmt_xdate()
plt.show()
