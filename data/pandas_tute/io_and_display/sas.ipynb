# %%
import pandas as pd

# %%
# read sas
df2 = pd.read_sas('europeancars.sas7bdat')
df2
# Out:
#          Make                          Model      Type     Origin DriveTrain  \
# 0     b'Audi'                b' A4 1.8T 4dr'  b'Sedan'  b'Europe'   b'Front'
# 1     b'Audi'     b' A41.8T convertible 2dr'  b'Sedan'  b'Europe'   b'Front'
# 2     b'Audi'                 b' A4 3.0 4dr'  b'Sedan'  b'Europe'   b'Front'
# 3     b'Audi'  b' A4 3.0 Quattro 4dr manual'  b'Sedan'  b'Europe'     b'All'
# 4     b'Audi'    b' A4 3.0 Quattro 4dr auto'  b'Sedan'  b'Europe'     b'All'
# ..        ...                            ...       ...        ...        ...
# 118  b'Volvo'    b' C70 LPT convertible 2dr'  b'Sedan'  b'Europe'   b'Front'
# 119  b'Volvo'    b' C70 HPT convertible 2dr'  b'Sedan'  b'Europe'   b'Front'
# 120  b'Volvo'                 b' S80 T6 4dr'  b'Sedan'  b'Europe'   b'Front'
# 121  b'Volvo'                        b' V40'  b'Wagon'  b'Europe'   b'Front'
# 122  b'Volvo'                       b' XC70'  b'Wagon'  b'Europe'     b'All'
#
# ...

# %%
_ = df2["Make"].iloc[0]
print(type(_))
_
# Out:
# <class 'bytes'>
# b'Audi'

# %%
# read in sas data, but not with the chars as bytes
df = pd.read_sas('europeancars.sas7bdat', encoding='utf-8')
df
# Out:
#       Make                       Model   Type  Origin DriveTrain     MSRP  \
# 0     Audi                 A4 1.8T 4dr  Sedan  Europe      Front  25940.0
# 1     Audi      A41.8T convertible 2dr  Sedan  Europe      Front  35940.0
# 2     Audi                  A4 3.0 4dr  Sedan  Europe      Front  31840.0
# 3     Audi   A4 3.0 Quattro 4dr manual  Sedan  Europe        All  33430.0
# 4     Audi     A4 3.0 Quattro 4dr auto  Sedan  Europe        All  34480.0
# ..     ...                         ...    ...     ...        ...      ...
# 118  Volvo     C70 LPT convertible 2dr  Sedan  Europe      Front  40565.0
# 119  Volvo     C70 HPT convertible 2dr  Sedan  Europe      Front  42565.0
# 120  Volvo                  S80 T6 4dr  Sedan  Europe      Front  45210.0
# 121  Volvo                         V40  Wagon  Europe      Front  26135.0
# 122  Volvo                        XC70  Wagon  Europe        All  35145.0
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
