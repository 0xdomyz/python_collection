# %%
import pandas as pd

# read csv
df = pd.read_csv('toydata/anagrams.csv')
df
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
# write as sas
df.to_sas('toydata/anagrams.sas7bdat')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2280/2889896510.py in ?()
#       1 # write as sas
# ----> 2 df.to_sas('toydata/anagrams.sas7bdat')
#
# ~/.local/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_sas'

# %%
# read sas
df2 = pd.read_sas('toydata/anagrams.sas7bdat')
df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/domyz/Projects/python_collection/data/sas.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/domyz/Projects/python_collection/data/sas.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # read sas
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/domyz/Projects/python_collection/data/sas.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df2 = pd.read_sas('toydata/anagrams.sas7bdat')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/domyz/Projects/python_collection/data/sas.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> df2
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/sas/sasreader.py:166, in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator, compression)
#     163 elif format.lower() == "sas7bdat":
# ...
